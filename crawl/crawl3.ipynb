# %%
# 요청(requests) => 결과가 html로 넘어오는 경우
# html에서 원하는 정보 찾기 => 파싱

# BeautifulSoup 라이브러리 사용
# pip install beautifulsoup4
# 파서
# 기본 파서 html.parser 설치 필요 없음
#           lxml 설치 필요
# pip install lxml

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("https://v.daum.net/v/20230707085248275")
# 두번째 인자로 파서 지정
# html.parser, lxml, lxml-xml, html5lib
soup = BeautifulSoup(r.text,"lxml")

# print(soup)
# print(soup.title)
print(soup.h3) # 처음 만나는 h3 태그 가져오기
print(soup.h3.string) # h3 안의 내용 가져오기
print(soup.h3.get_text())
# Out:
# <h3 class="tit_view" data-translation="true">서울 아파트 매수심리 18주 연속 올랐다…지방은 하락세 지속</h3>
# 서울 아파트 매수심리 18주 연속 올랐다…지방은 하락세 지속
# 서울 아파트 매수심리 18주 연속 올랐다…지방은 하락세 지속

# %%
# story.html
from bs4 import BeautifulSoup
with open("./story.html","r") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <h1>
#    H1 Area
#   </h1>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" data-io="test" href="http://example.com/tillie" id="link2">
#     Tillie
#    </a>
#    ; and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
# 태그를 이용한 정보 찾기

# title 태그 찾기
print(soup.title)
# title 태그가 가지고 있는 내용 찾기
print(soup.title.string)
# title 태그의 부모 찾기
print(soup.title.parent)
# Out:
# <title>The Dormouse's story</title>
# The Dormouse's story
# <head>
# <title>The Dormouse's story</title>
# </head>

# %%
# h1 태그 찾기
print(soup.h1)
print(soup.h1.string)
# Out:
# <h1>H1 Area</h1>
# H1 Area

# %%
# p 태그 찾기 - 가장 처음 만나는 p 태그 찾기
print(soup.p)
print(soup.string)
print(soup.p.get_text())
print(soup.p.get_text().strip())
print(soup.p["class"]) # 속성 찾기 - 결과가 리스트로 돌아옴
# Out:
# <p class="title">
# <b> The Dormouse's story </b>
# </p>
# None
#
#  The Dormouse's story
#
# The Dormouse's story
# ['title']

# %%
# b 태그 찾기
print(soup.b)
print(soup.b.get_text())
print(soup.b.get_text().strip())
# Out:
# <b> The Dormouse's story </b>
#  The Dormouse's story
# The Dormouse's story

# %%
# find() : 가장 처음 만나는 태그
# find_all() : 모든 태그
print(soup.find("h1"))
print(soup.find("h1").string)
# Out:
# <h1>H1 Area</h1>
# H1 Area

# %%
print(soup.find_all("p"))
# Out:
# [<p class="title">
# <b> The Dormouse's story </b>
# </p>, <p class="story">
#       Once upon a time there were three little sisters; and their names were
#       <a class="sister" href="http://example.com/elsie" id="link1"> Elsie </a>
#       ,
#       <a class="sister" href="http://example.com/lacie" id="link2"> Lacie </a>
#       and
#       <a class="sister" href="http://example.com/tillie" id="link2"> Tillie </a>
#       ; and they lived at the bottom of a well.
#     </p>, <p class="story">...</p>]

# %%
# 찾은 태그가 하나여도 결과는 무조건 리스트임
# print(soup.find_all("p"))
for tag in soup.find_all("p"):
    print(tag)
# Out:
# <p class="title">
# <b> The Dormouse's story </b>
# </p>
# <p class="story">
#       Once upon a time there were three little sisters; and their names were
#       <a class="sister" href="http://example.com/elsie" id="link1"> Elsie </a>
#       ,
#       <a class="sister" href="http://example.com/lacie" id="link2"> Lacie </a>
#       and
#       <a class="sister" href="http://example.com/tillie" id="link2"> Tillie </a>
#       ; and they lived at the bottom of a well.
#     </p>
# <p class="story">...</p>

# %%
print(soup.find_all("p",class_="story"))
# Out:
# [<p class="story">
#       Once upon a time there were three little sisters; and their names were
#       <a class="sister" href="http://example.com/elsie" id="link1"> Elsie </a>
#       ,
#       <a class="sister" href="http://example.com/lacie" id="link2"> Lacie </a>
#       and
#       <a class="sister" href="http://example.com/tillie" id="link2"> Tillie </a>
#       ; and they lived at the bottom of a well.
#     </p>, <p class="story">...</p>]

# %%
print(soup.find_all("a"))
print(soup.find_all("a", class_="sister"))

for link in soup.find_all("a"):
    print(link.get("href"))

print(soup.find_all("a",limit=2))
print(soup.find_all("a",string=["Elsie"]))
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1"> Elsie </a>, <a class="sister" href="http://example.com/lacie" id="link2"> Lacie </a>, <a class="sister" href="http://example.com/tillie" id="link2"> Tillie </a>]
# [<a class="sister" href="http://example.com/elsie" id="link1"> Elsie </a>, <a class="sister" href="http://example.com/lacie" id="link2"> Lacie </a>, <a class="sister" href="http://example.com/tillie" id="link2"> Tillie </a>]
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie
# [<a class="sister" href="http://example.com/elsie" id="link1"> Elsie </a>, <a class="sister" href="http://example.com/lacie" id="link2"> Lacie </a>]
# []

# %%
# find("a", class="", limit=2, string=["Elsie"], id=""), find_all() :
# class_ : 클래스명 추가 지정 
# limit : 가져오는 개수 제한
# string : 문자
# id : id 속성

a_tag = soup.find("a", id="link1", class_="sister")
print(a_tag)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
a_tag = soup.find("a", attrs={"data-io":"test","class":"sister"})
print(a_tag)
# Out:
# <a class="sister" data-io="test" href="http://example.com/tillie" id="link2">Tillie</a>

# %%
# 웹 요청 + 파싱

import requests
from bs4 import BeautifulSoup

res = requests.get("https://pythonscraping.com/pages/warandpeace.html")
# print(res.text)
soup = BeautifulSoup(res.text, "html.parser") # lxml

# html 모든 문자 가져오기
# print(soup.get_text())

# 등장인물 가져오기
# persons = soup.findAll("span", class_="green")
# for person in persons:
#     print(person.string)

# 대사 가져오기
contents = soup.findAll("span", attrs={"class":"red"})
for content in contents:
    print(content.string)
# Out:
# Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news.
# If you have nothing better to do, Count [or Prince], and if the
# prospect of spending an evening with a poor invalid is not too
# terrible, I shall be very charmed to see you tonight between 7 and 10-
# Annette Scherer.
# Heavens! what a virulent attack!
# First of all, dear friend, tell me how you are. Set your friend's
# mind at rest,
# Can one be well while suffering morally? Can one be calm in times
# like these if one has any feeling?
# You are
# staying the whole evening, I hope?
# And the fete at the English ambassador's? Today is Wednesday. I
# must put in an appearance there,
# My daughter is
# coming for me to take me there.
# I thought today's fete had been canceled. I confess all these
# festivities and fireworks are becoming wearisome.
# If they had known that you wished it, the entertainment would
# have been put off,
# Don't tease! Well, and what has been decided about Novosiltsev's
# dispatch? You know everything.
# What can one say about it?
# What has been decided? They have decided that
# Buonaparte has burnt his boats, and I believe that we are ready to
# burn ours.
# Oh, don't speak to me of Austria. Perhaps I don't understand
# things, but Austria never has wished, and does not wish, for war.
# She is betraying us! Russia alone must save Europe. Our gracious
# sovereign recognizes his high vocation and will be true to it. That is
# the one thing I have faith in! Our good and wonderful sovereign has to
# perform the noblest role on earth, and he is so virtuous and noble
# that God will not forsake him. He will fulfill his vocation and
# crush the hydra of revolution, which has become more terrible than
# ever in the person of this murderer and villain! We alone must
# avenge the blood of the just one.... Whom, I ask you, can we rely
# on?... England with her commercial spirit will not and cannot
# understand the Emperor Alexander's loftiness of soul. She has
# refused to evacuate Malta. She wanted to find, and still seeks, some
# secret motive in our actions. What answer did Novosiltsev get? None.
# The English have not understood and cannot understand the
# self-abnegation of our Emperor who wants nothing for himself, but only
# desires the good of mankind. And what have they promised? Nothing! And
# what little they have promised they will not perform! Prussia has
# always declared that Buonaparte is invincible, and that all Europe
# is powerless before him.... And I don't believe a word that Hardenburg
# says, or Haugwitz either. This famous Prussian neutrality is just a
# trap. I have faith only in God and the lofty destiny of our adored
# monarch. He will save Europe!
# I think,
# None
# In a moment. A propos,
# None
# I shall be delighted to meet them,
# But tell me,
# is it true that the Dowager Empress wants Baron Funke
# to be appointed first secretary at Vienna? The baron by all accounts
# is a poor creature.
# Baron Funke has been recommended to the Dowager Empress by her
# sister,
# Now about your family. Do you know that since your daughter came
# out everyone has been enraptured by her? They say she is amazingly
# beautiful.
# I often think,
# None
# Two such charming children. And really you appreciate
# them less than anyone, and so you don't deserve to have them.
# I can't help it,
# Lavater would have said I
# lack the bump of paternity.
# Don't joke; I mean to have a serious talk with you. Do you know I
# am dissatisfied with your younger son? Between ourselves
# he was mentioned at Her
# Majesty's and you were pitied....
# What would you have me do?
# You know I did all
# a father could for their education, and they have both turned out
# fools. Hippolyte is at least a quiet fool, but Anatole is an active
# one. That is the only difference between them.
# And why are children born to such men as you? If you were not a
# father there would be nothing I could reproach you with,
# I am your faithful slave and to you alone I can confess that my
# children are the bane of my life. It is the cross I have to bear. That
# is how I explain it to myself. It can't be helped!

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://v.daum.net/v/20230710100514542")

soup = BeautifulSoup(res.text,"lxml")

# 뉴스 제목
title = soup.find("h3", class_="tit_view")
print(title)
print(title.string)

# 작성자
writer = soup.find("span", class_="txt_info")
print(writer)
print(writer.string)

# 작성날짜와 시간
date_time = soup.find("span", class_="num_date")
print(date_time)
print(date_time.string)

# 첫번째 문단
para = soup.find("p", attrs={"dmcf-pid":"zlxhrfiH8w","dmcf-ptype":"general"})
print(para)
print(para.string)

para1 = soup.find_all("p", attrs={"dmcf-ptype":"general"})
print(para1[0].string)
# Out:
# <h3 class="tit_view" data-translation="true">尹 지지율 3주간 오름세 멈춰… 2.9%p 하락한 39.1%</h3>
# 尹 지지율 3주간 오름세 멈춰… 2.9%p 하락한 39.1%
# <span class="txt_info">오장연 기자</span>
# 오장연 기자
# <span class="num_date">2023. 7. 10. 10:05</span>
# 2023. 7. 10. 10:05
# <p dmcf-pid="zlxhrfiH8w" dmcf-ptype="general"> 윤석열 대통령의 국정수행 긍정 평가가 3주 동안의 오름세를 멈추고 하락했다는 여론조사 결과가 10일 나왔다.</p>
#  윤석열 대통령의 국정수행 긍정 평가가 3주 동안의 오름세를 멈추고 하락했다는 여론조사 결과가 10일 나왔다.
#  윤석열 대통령의 국정수행 긍정 평가가 3주 동안의 오름세를 멈추고 하락했다는 여론조사 결과가 10일 나왔다.

# %%
# 네이버 쇼핑 카테고리
import requests
from bs4 import BeautifulSoup

res = requests.get("https://shopping.naver.com/home")

soup = BeautifulSoup(res.text,"html.parser")

categories = soup.find_all("li", class_="category_list__y8A1h")

for category in categories:
    print(category.get_text())
# Out:
# 장마준비
# 여름휴가
# 여성패션
# 남성패션
# 화장품/미용
# 가구/인테리어
# 식품
# 출산/유아동
# 반려동물용품
# 생활/주방용품
# 가전

# %%
# find(), find_all()
# select_one(), select() : css 선택자 사용 가능

from bs4 import BeautifulSoup
with open("./story.html","r") as f:
    html = f.read()

soup = BeautifulSoup(html, "html.parser")
# print(soup.prettify())

# b 태그 찾기
b_tag = soup.select_one("p.title > b")
print(b_tag)
# Out:
# <b> The Dormouse's story </b>

# %%
p_tag = soup.select_one("p.story")
print(p_tag)
# Out:
# <p class="story">
#       Once upon a time there were three little sisters; and their names were
#       <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
#       ,
#       <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
#       and
#       <a class="sister" data-io="test" href="http://example.com/tillie" id="link2">Tillie</a>
#       ; and they lived at the bottom of a well.
#     </p>

# %%
a_tag = soup.select_one("#link1")
print(a_tag)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
a_tag = soup.select_one("a[data-io='test']")
print(a_tag)
# Out:
# <a class="sister" data-io="test" href="http://example.com/tillie" id="link2">Tillie</a>

# %%
a_tags = soup.select("p.story > a")
print(a_tags)
for a in a_tags:
    print(a.string)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" data-io="test" href="http://example.com/tillie" id="link2">Tillie</a>]
# Elsie
# Lacie
# Tillie

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get("https://v.daum.net/v/20230710100514542")

soup = BeautifulSoup(res.text,"lxml")

# 뉴스 제목
title = soup.select_one("h3")
print(title)
print(title.string)

# 작성자
writer = soup.select_one("span.txt_info")
print(writer)
print(writer.string)

# 작성날짜와 시간
date_time = soup.select_one("span.num_date")
print(date_time)
print(date_time.string)

# 첫번째 문단
para = soup.select_one("p[dmcf-pid='zlxhrfiH8w']")
print(para)
print(para.string)

para1 = soup.select("p[dmcf-ptype='general']")
print(para1[0].string)
# Out:
# <h3 class="tit_view" data-translation="true">尹 지지율 3주간 오름세 멈춰… 2.9%p 하락한 39.1%</h3>
# 尹 지지율 3주간 오름세 멈춰… 2.9%p 하락한 39.1%
# <span class="txt_info">오장연 기자</span>
# 오장연 기자
# <span class="num_date">2023. 7. 10. 10:05</span>
# 2023. 7. 10. 10:05
# <p dmcf-pid="zlxhrfiH8w" dmcf-ptype="general"> 윤석열 대통령의 국정수행 긍정 평가가 3주 동안의 오름세를 멈추고 하락했다는 여론조사 결과가 10일 나왔다.</p>
#  윤석열 대통령의 국정수행 긍정 평가가 3주 동안의 오름세를 멈추고 하락했다는 여론조사 결과가 10일 나왔다.
#  윤석열 대통령의 국정수행 긍정 평가가 3주 동안의 오름세를 멈추고 하락했다는 여론조사 결과가 10일 나왔다.

# %%
# https://pythonscraping.com/pages/warandpeace.html



import requests
from bs4 import BeautifulSoup

res = requests.get("https://pythonscraping.com/pages/page3.html")
soup = BeautifulSoup(res.text,"html.parser")

# Totally Normal Gifts 추출
title = soup.select_one("h1") # title = soup.select_one("h1")
print(title.string)

# 모든 img 태그 추출(제목 행 옆 이미지 제외)
imgs = soup.select("#giftList img")
for img in imgs:
    print(img)
    print(img["src"])
    print(img.get("src"))

# 테이블 내용추출
tables = soup.select("#giftList")
for item in tables:
    print(item.get_text().strip())
# Out:
# Totally Normal Gifts
# <img src="../img/gifts/img1.jpg"/>
# ../img/gifts/img1.jpg
# ../img/gifts/img1.jpg
# <img src="../img/gifts/img2.jpg"/>
# ../img/gifts/img2.jpg
# ../img/gifts/img2.jpg
# <img src="../img/gifts/img3.jpg"/>
# ../img/gifts/img3.jpg
# ../img/gifts/img3.jpg
# <img src="../img/gifts/img4.jpg"/>
# ../img/gifts/img4.jpg
# ../img/gifts/img4.jpg
# <img src="../img/gifts/img6.jpg"/>
# ../img/gifts/img6.jpg
# ../img/gifts/img6.jpg
# Item Title
#
# Description
#
# Cost
#
# Image
#
#
# Vegetable Basket
#
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# Now with super-colorful bell peppers!
#
# $15.00
#
#
#
#
# Russian Nesting Dolls
#
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! 8 entire dolls per set! Octuple the presents!
#
# $10,000.52
#
#
#
#
# Fish Painting
#
# If something seems fishy about this painting, it's because it's a fish! Also hand-painted by trained monkeys!
#
# $10,005.00
#
#
#
#
# Dead Parrot
#
# This is an ex-parrot! Or maybe he's only resting?
#
# $0.50
#
#
#
#
# Mystery Box
#
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. Keep your friends guessing!
#
# $1.50

# %%
# clien 팁과 강좌 게시판(1~5 page) 타이틀 추출

# https://www.clien.net/service/board/lecture

# https://www.clien.net/service/board/lecture?&od=T31&category=0&po=1
# https://www.clien.net/service/board/lecture?&od=T31&category=0&po=2
# https://www.clien.net/service/board/lecture?&od=T31&category=0&po=3
# https://www.clien.net/service/board/lecture?&od=T31&category=0&po=4

for page_num in range(5):
    if page_num == 0:
        res = requests.get("https://www.clien.net/service/board/lecture")
    else:
        res = requests.get("https://www.clien.net/service/board/lecture?&od=T31&category=0&po="+str(page_num))
    
    soup = BeautifulSoup(res.text,"lxml")

    # title 추출
    titles = soup.select("span.subject_fixed")
    for title in titles:
        print(title.string.strip())
# Out:
# 세탁시 살균을 위한 구연산 농도
# 애플 비전 프로 개발을 위한 Xcode Beta Preview 사용해보기
# 아이폰 14 프로 RFID 스티커 위치 입니다.
# (헛소리로 판명) 애플 비전 프로 국내 정발이 불가능한 이유
# 구글드라이브에 있는 사진을 링크로 공유하는 법
# MS 게임패스 얼티밋 변환 비율 수정
# 서울대공원에 주차 할인 해주네요
# 유튜브 뮤직 모바일에 댓글 기능 및 추가 바로가기 액션이 생겼습니다
# 아이 자전거 개조기(핸들바 높이 높이기)
# WEBP 저장되는 이미지를 PNG 로 저장 (PC, 엣지)
# 첫 단독 캠핑으로 현대 포터 캠핑카, 포레스트 사용기 (Feat. 가평 밤벌오토캠핑장)
# 노래 흥얼거리기(허밍)로 제목 찾기
# 아이폰에서 LDAC 사용 (기존 클리앙글 인용과 업데이트, 소노플로우, 샨링, M0, Q45)
# [주간 코로나] 06월 4주 (06. 25. - 07. 01.) - 분석편 - <3주년 기념호>
# [자동차] 재규어 / 랜드로버 부품 가격 조회
# 영어 연재글 Q:열심히 하면 갑자기 귀가 뚫리죠?
# 마팁)짜증나는 엑셀 앞뒤 빈 값 처리
# 플래시카드 서비스 사용기(quizlet)
# 의외로(?)순수 라틴어와 그리스어(출신 라틴어)의 구별이 유용한 이유 (의료영어위주)
# [주간 코로나] 06월 4주 (06. 25. - 07. 01.) - 통계편 -
# [코로나 정보] 만성 코로나19 증후군과 코로나19 예방접종
# 공부 13편 ㅡ 공부에서 중요한 분별 대상
# 전기밥솥 쿠쿠의 내구성은 사용자 문제
# VoLTE 미사용시 미세팁
# 다크모드 강제 해제로 인한 힘든분들 보세요~
# 거의 모든 자기계발서 요약 10계명
# 벽돌 된 레노버 스마트 디스플레이 10' 살리기
# 맥북 활용 꿀팁 (윈도우에서 맥북으로 갈아타고 적용 팁)
# 다크모드 버그 있으신 분들 한 번 시도해 보세요.
# 다크모드 설정 방법
# 우울감이 자주 찾아오는 사람을 위한 습관 하나.
# 소소한 여행객이 덧붙여보는 여행 꿀팁
# [주간 코로나] 06월 3주 (06. 18. - 06. 24.) - 분석편 -
# 독특한 색감을 만들어내는 방법 : 그랜드부다페스트 호텔 (feat. 질 보그다노비치)
# 영어 연재글 Q:> 영어 시험들은 다 쓰레기죠?
# 인간의 비이성적행동법칙과 인간 본성의 18가지 법칙에 대한 간단한 정리
# 맥 + 키보드마에스트로 + 스트림덱 활용기
# 페달과 계기판, 바깥이 함께 보이는 블랙박스-'천장 블랙박스'
# [주간 코로나] 06월 3주 (06. 18. - 06. 24.) - 통계편 - <통권 150호>
# 99만원으로 게이밍 PC 견적을 내보자
# 제발 독도는 우리땅이라고 우기지 맙시다. (1)
# 모기 물렸을때 파스 안쓰고 가렵지 않게 하는 법(화상주의)
# termux 우분투 셋팅법
# 자녀에게 영어책 읽어주기 (3) - 미국 도서관에 회원가입
# 사진앱 4302 오류로 인하여 라이브러리를 열 수 없는 경우 해결법
# 인상 깊은 프레젠테이션을 위한 습관과 태도를 말에 입히기
# 서피스 랩탑5 SSD 교체 쉽습니다
# 자녀에게 영어책 읽어주기 (2) - Libby 앱 사용
# 신용카드 부정사용 신고 팁
# PPT 파일안에 원본이미지 추출하기
# 노트북 고르기 (에 조금은 도움이 될 수 있는 글)
# 아이폰 텍스트 입력, 취소, 복사, 붙이기 팁
# 자녀에게 영어책 읽어주기 - 최대 전자책 플랫폼 '오버드라이브' 사용
# [주간 코로나] 06월 2주 (06. 11. - 06. 17.) - 분석편 -
# AMD 노트북 CPU 간단 정리 (Amd mobile processors)
# ios17의 핵심 기능인 대기모드의 자세한 사용법과 정보입니다.
# [손톱만한팁] Logitec MX Vertical 끈적임 중-단기 해소방법
# 아들님 동네 친구들과 부모님을 위한 밥상
# 극한의 위생관리, 감기예방 최적화 후기
# [주간 코로나] 06월 2주 (06. 11. - 06. 17.) - 통계편 -
# [교직원 대상 HWP자동화 튜토리얼 영상] 요즘 또 유학생 모집 기간이죠?ㅜ
# 영어 연재글: Q>영어 발음은 필요없죠?
# 클리앙과 같은 온라인 커뮤니티 만들어내는 방법
# 인상 깊은 프레젠테이션을 만드는 습관
# 오토핫키 기능 몇 가지 autohotkey AutoHotKey AHK
# [주간 코로나] 06월 1주 (06. 04. - 06. 10.) - 분석편 -
# xbox 원격플레이가 잘 안될때 해결법
# 선풍기 바람이 시원찮을 때 - 부품 교체기
# JPEG XL과 조용한 차세대 이미지 포맷 전쟁
# 영어 연재 글> Q:'영어 문법 공부는 필요 없죠?'
# 인상 깊은 프레젠테이션을 만드는 태도.
# 2023年 기준 美아마존 반품記
# [주간 코로나] 06월 1주 (06. 04. - 06. 10.) - 통계편 -
# 공부 13편 ㅡ 공부에서 중요한 것
# 뒤늦은 코로나 발병기
# 유니티로 간단한 게임 만들기
# 차에서 태블릿 사용 / 발열문제 해결책
# chatgpt에서 만든 마크다운을 마인드맵으로 간단하게 사용하기
# 싱가포르 한주간 여행 후기겸 개인적 팁
# [주간 코로나] 05월 5주 - 분석편 - (05. 28. - 06. 03.)
# 카시트 잘 태우기에 대한 이야기
# 미국 여행시 에어비앤비/민박은 주의하시길 바랍니다. - 도시법/규정 문제
# LED스트립만 연결해서 모니터 앰비언트를 만들어보자.
# [주간 코로나] 05월 5주 - 통계편 - <통권 147호>
# 상남자의 sata ssd2개 레이드0 비교기 (바이오스 vs 윈도우 2종)
# 대란에 ssd를 샀어요 방열판 꼭 달아야 하나요? 구리를 사야해요? 알루미늄 사야해요?
# 존윅4 불꽃샷건을 장난감총으로 따라해 보자
# [팁] 1분 안에 키보드 청소하는 법
# 써멀구리스의 중요성
# 포토샵 뺨치는 짭토샵 인공지능.GIF
# 외국 느낌의 데스크셋업 만들기
# 개인적인 영어 학습법입니다.
# 제네시스, 스마트폰을 차키로! 디지털 키 등록 방법 A to Z
# 인공지능으로 윤석열 제거하기.JPG
# Part3>영어 독해력을 키운다? 원서를 읽는 고행을 결심한 소수의 사람들에게
# 알리발 더스트건 간단사용후기
# 서울시 경계경보 담당자를 위한 경계경보 발령 강좌
# [코로나 정보] 코로나19 대응 지침 개정
# [코로나 단신] 05월 4주 - 분석편 -
# [주간 코로나] 05월 4주 - 통계편 - <통권 146호>
# Mac Arm CPU에서 WMware - Win11 ARM(가상) 활용방법(파일공유, 외부장치 연결 등)
# 울릉도 특산물 팁 - 호박 -
# AI를 사용해서 썸네일 쉽게 만드는 법
# 남몰래 야동 보는 3가지 비법.TXT
# 맥 Mac 화면 깜빡임 해결기 (맥북프로 유저)
# VMware Fusion을 이용하여 Mac Arm CPU에서 Windows 11 ARM 설치하기
# Plex Media Server 이번 약관 업데이트로 스마트TV 연동 안되시는 분
# Windows PowerShell 예쁘게 꾸미기
# 다 막았는데 왜 모기가 집안에 있을까? (하수구)
# 칫솔질을 이렇게 하니 더 깨끗해 졌습니다.
# 제대로 건강해지고 싶다면 이 운동을 하시면 됩니다.
# 우울감 (우울증, 스트레스) 대처 순서
# 턱관절 장애. 스트레칭 요고 강추합니다!!
# [주간 코로나] 05월 3주 - 분석편 -
# 커넥션 (6) 카타고의 참패와 인공지능의 허점
# [주간 코로나] 05월 3주 - 통계편 - <통권 145호>
# 유튜브 채널 관리(App + Chrome확장팩) 써보니 편하고 좋습니다.
# 윈도우 터미널,CMD 관리자 권한으로 실행하기...
# 로지텍 MX Keys 키보드 백라이트가 자동으로 안꺼질 때
# 소형 잡동사니 정리방법
# 1등급 tv는 어떻게 만들어지나
# 공부 단상 연재 12편
# 시니어를 위한 'EBS 평생학교'를 소개합니다.
# 이미지->PDF 변환 텔레그램 봇 만들기
# 애플워치 손목에 차지 않고 맥북 열기(잠금해제)
# [주간 코로나] 05월 2주 - 분석편 -
# 정수기 자작 이동식 파우셋
# SSD 핫딜에 SSD 사려는 SSD 알못이라면 꼭 읽었으면 좋겠읍미다.
# PDF 파일 크롭하기
# 2023 Ver. 파세코 에어컨 (창문형 에어컨) 설치 후 외부소음차단하기
# 안보시는 TV 수신료 해지 및 환불 방법
# 구글 검색결과 클릭 빗나갈 때 이미지 검색 납치 방지하기
# 서피스 듀오 PTA-VOLTE에서 KT Volte 안되는 현상 해결 건
# 5분이면 충분해! 영어를 몰라도 쉽게 따라할 수 있는 고퀄리티 Ai편집
# 모니터 화면 쉽게 회전. 인텔 그래픽카드 아니어도 피봇,화면 회전 가능
# 인텔 글픽 전용! 모니터 화면회전 : 고개 돌리지 않고 사진보기
# 블렌더 강좌 - 블렌더로 바탕화면 만들기
# 저시력자 가독성 높인 온고딕 서체 (한국장애인개발원 개발)
# 레인지후드 자동화 - 열화상센서 온도 활용, 홈어시스턴트(HA)[내용 추가]
# [주간 코로나] 05월 2주 - 통계편 - <통권 144호>

# %%
# 구글 뉴스 - 파이썬
keyword = input("검색어 입력")

url = "https://news.google.com/search?q="+keyword+"&hl=ko&gl=KR&ceid=KR%3Ako"

res = requests.get(url)
soup = BeautifulSoup(res.text,"lxml")

# 화면에 보이는 모든 article 가져오기
articles = soup.select("div.xrnccd article")
for article in articles:
    # print(article)    
    # 제목
    # print(article.select_one("h3").string)
    # print(article.h3.string)
    title = article.h3.string
    # 링크
    link = article.a["href"]
    # 작성자 
    writer = article.img.get("alt")
    # 작성날짜 
    date = article.time.string

    print(title, link, writer, date)
# Out:
# [영상:THISCovery] 스타벅스 경동1960점 가면 매운맛 냉면은 필수! ./articles/CBMiQGh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9zb2NpZXR5L3NvY2lldHlfZ2VuZXJhbC8xMDk4NTc5Lmh0bWzSAQA?hl=ko&gl=KR&ceid=KR%3Ako 한겨레 6일 전
# 너무 비싼 평양냉면, 그런데 그만 빠져버렸습니다 ./articles/CBMiRGh0dHBzOi8vd3d3Lm9obXluZXdzLmNvbS9OV1NfV2ViL1ZpZXcvYXRfcGcuYXNweD9DTlROX0NEPUEwMDAyOTQxODk20gFCaHR0cHM6Ly9tLm9obXluZXdzLmNvbS9OV1NfV2ViL01vYmlsZS9hbXAuYXNweD9DTlROX0NEPUEwMDAyOTQxODk2?hl=ko&gl=KR&ceid=KR%3Ako 오마이뉴스 2일 전
# 올여름 냉면 가격이 '오싹'…유명 맛집은 1만5천원도 우습지 ./articles/CBMiOWh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9lY29ub215L2NvbnN1bWVyLzEwOTY1MTAuaHRtbNIBAA?hl=ko&gl=KR&ceid=KR%3Ako 한겨레 6월 19일
# 연수구, 지역 어르신 위한 후원물품 '사랑의 냉면' 전달 받아 ./articles/CBMiOGh0dHA6Ly93d3cueWVvbnN1LmluZm8vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTQ1MzI20gEA?hl=ko&gl=KR&ceid=KR%3Ako 연수신문 4일 전
# "평양냉면의 시대가 오기를 기다렸다." 육수로 승부수 던진 김태현 벽제 ... ./articles/CBMiOWh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTYwMzY5N9IBPGh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTYwMzY5Nw?hl=ko&gl=KR&ceid=KR%3Ako 블로터 1시간 전
# '생활의달인' 은둔식달–평양냉면·밀면, 의정부 도시락 아빠, 상위 1 ... ./articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyOTUxONIBAA?hl=ko&gl=KR&ceid=KR%3Ako 한국강사신문 6월 26일
# [이거야!ONE] 남북 정상 만날 때 마다 평양냉면 먹는 이유? ./articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNl8yMDIzMDYzMDE5MTg0Njk1NzfSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDZfMjAyMzA2MzAxOTE4NDY5NTc3?hl=ko&gl=KR&ceid=KR%3Ako YTN 6월 30일
# 맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는… ./articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako news.kmib.co.kr 6월 18일
# "배 타고 왕복 8시간..'냉면 킬러'의 전국 평양냉면 탐방기" ./articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako 노컷뉴스 6월 24일
# 슴슴한 맛이 당길 때, 평양냉면 ./articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako 노블레스닷컴 6월 9일
# [화제의 맛] 올 여름 다양한 냉면이 온다 ./articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako 식품외식경영 6월 27일
# 삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려" ./articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako 아시아타임즈 7일 전
# [영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면' ./articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako 자유아시아방송 6월 20일
# 삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네 ./articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako 머니투데이 6월 28일
# 평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니 ./articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako 시사저널e 9일 전
# 풀무원 '고메밀물냉면' 내세워 中 홀린다 ./articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako The Guru (더 구루) 6월 19일
# 식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시 ./articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako 동아일보 6일 전
# 여름 대표 메뉴 삼계탕·냉면 가격 들썩 ./articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako 강원일보 6월 15일
# '생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ... ./articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako 한국강사신문 6월 12일
# 평양냉면 먹방 찍더니…北유튜버 돌연 사라진 이유가 ./articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI0MTYyNTEzODQ1MzTSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyNDE2MjUxMzg0NTM0?hl=ko&gl=KR&ceid=KR%3Ako 머니투데이 6월 24일
# 면사랑의 대표 여름면 냉동밀키트 '삼선중식냉면', 카카오메이커스 ... ./articles/CBMiNWh0dHBzOi8vbmV3cy5pbWFlaWwuY29tL3BhZ2Uvdmlldy8yMDIzMDYyNzExNDI1Mjc2Mjk10gEA?hl=ko&gl=KR&ceid=KR%3Ako 매일신문 6월 27일
# 뜨거운 날씨에 시원한 냉면 찾는 시민들 ./articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjE5NDLSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjE5NDI?hl=ko&gl=KR&ceid=KR%3Ako 노컷뉴스 6월 19일
# 증평군, 김밥·냉면집 등 달걀취급 음식점 대상 식중독 예방 홍보 ./articles/CBMiOWh0dHA6Ly93d3cuamJuZXdzLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTM5OTI5N9IBPGh0dHA6Ly93d3cuamJuZXdzLmNvbS9uZXdzL2FydGljbGVWaWV3QW1wLmh0bWw_aWR4bm89MTM5OTI5Nw?hl=ko&gl=KR&ceid=KR%3Ako 중부매일 7일 전
# 김대호 아나운서가 퇴근 후 다녀간 맛집 4 ./articles/CBMiLGh0dHBzOi8vd3d3LmVzcXVpcmVrb3JlYS5jby5rci9hcnRpY2xlLzc4ODQ50gEA?hl=ko&gl=KR&ceid=KR%3Ako 에스콰이어 9일 전
# 더테이스터블, 홍삼불도장·중화냉면 등 여름 신메뉴 선보여 ./articles/CBMiNmh0dHA6Ly93d3cubmV3c2tyLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz05MDg3NdIBOWh0dHA6Ly93d3cubmV3c2tyLmtyL25ld3MvYXJ0aWNsZVZpZXdBbXAuaHRtbD9pZHhubz05MDg3NQ?hl=ko&gl=KR&ceid=KR%3Ako 한국농어촌방송 6월 19일
# 정모 "명카드라이브의 '냉면'은 중의적 의미, 제시카·박명수 씨의 차가운 얼굴 뜻해" (정희) ./articles/CBMiQmh0dHBzOi8vaW1uZXdzLmltYmMuY29tL25ld3MvMjAyMy9lbnRlci9hcnRpY2xlLzY0OTc1NzdfMzYxNjEuaHRtbNIBQmh0dHBzOi8vaW1uZXdzLmltYmMuY29tL25ld3MvMjAyMy9lbnRlci9hcnRpY2xlLzY0OTc1NzdfMzYxNjIuaHRtbA?hl=ko&gl=KR&ceid=KR%3Ako MBC뉴스 6월 27일
# 냉면 가격에 깜짝 놀랐다면…이번엔 '삼계탕' 차례 [이미경의 인사이트] ./articles/CBMiNmh0dHBzOi8vd3d3Lmhhbmt5dW5nLmNvbS9lY29ub215L2FydGljbGUvMjAyMzA3MDI4MjYwadIBMmh0dHBzOi8vd3d3Lmhhbmt5dW5nLmNvbS9lY29ub215L2FtcC8yMDIzMDcwMjgyNjBp?hl=ko&gl=KR&ceid=KR%3Ako 한국경제 8일 전
# 평양냉면 같은 슴슴한 방송, 맛 보러 오세요 [취재 뒷담화] ./articles/CBMiOmh0dHBzOi8vd3d3LnNpc2Fpbi5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NTA1MzfSAT1odHRwczovL3d3dy5zaXNhaW4uY28ua3IvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTUwNTM3?hl=ko&gl=KR&ceid=KR%3Ako 시사IN(시사인) 6월 16일
# 33떡볶이&꼬마김밥, 여름철 새콤달콤 '열무냉면' 함께해요 ./articles/CBMiPmh0dHA6Ly93d3cuc2hpbmFpbGJvLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xNzE4MTQ30gEA?hl=ko&gl=KR&ceid=KR%3Ako 신아일보 6월 16일
# 평양냉면에 진심인 바리톤 절친의 ‘일 트로바토레’ ./articles/CBMiO2h0dHBzOi8vd3d3LnNlb3VsLmNvLmtyL25ld3MvbmV3c1ZpZXcucGhwP2lkPTIwMjMwNjE4NTAwMTIx0gEsaHR0cHM6Ly9hbXAuc2VvdWwuY28ua3Ivc2VvdWwvMjAyMzA2MTg1MDAxMjE?hl=ko&gl=KR&ceid=KR%3Ako 서울신문 6월 18일
# 더위 식히는 냉면·아이스크림 쿨 푸드 너무 올랐네 ./articles/CBMiPWh0dHBzOi8vbWJuLmNvLmtyL3BhZ2VzL25ld3MvbmV3c1ZpZXcucGhwP25ld3Nfc2VxX25vPTQ5MzkwOTHSAQA?hl=ko&gl=KR&ceid=KR%3Ako MBN 6월 19일
# '생활의 달인 - 은둔식달' 평양냉면·밀면 달인 '중독성 강한 양념장 맛' ./articles/CBMiOmh0dHBzOi8vd3d3Lmhhbmtvb2tpLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89ODcxMjTSAT1odHRwczovL3d3dy5oYW5rb29raS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTg3MTI0?hl=ko&gl=KR&ceid=KR%3Ako 한국아이닷컴 6월 26일
# 100년 전통 밀면집은 식초를 넣을까? 내호냉면 4대 사장 유재우 [부산 ... ./articles/CBMiRWh0dHBzOi8vbW9iaWxlLmJ1c2FuLmNvbS92aWV3L2J1c2FuL3ZpZXcucGhwP2NvZGU9MjAyMzA2MTYxNTI4MzkwNDU4NtIBAA?hl=ko&gl=KR&ceid=KR%3Ako 부산일보 6월 23일
# 냉면집 문전성시 ./articles/CBMiL2h0dHBzOi8vd3d3LnluYS5jby5rci92aWV3L1BZSDIwMjMwNjE4MDMyMzAwMDEz0gExaHR0cHM6Ly9tLnluYS5jby5rci9hbXAvdmlldy9QWUgyMDIzMDYxODAzMjMwMDAxMw?hl=ko&gl=KR&ceid=KR%3Ako 연합뉴스 6월 18일
# '워크맨2' 장성규, 평양냉면 알바생으로 변신…입담 '大폭발' ./articles/CBMiO2h0dHBzOi8vdGVuYXNpYS5oYW5reXVuZy5jb20vdHYtZHJhbWEvYXJ0aWNsZS8yMDIzMDYyMzg2NDE00gE3aHR0cHM6Ly90ZW5hc2lhLmhhbmt5dW5nLmNvbS90di1kcmFtYS9hbXAvMjAyMzA2MjM4NjQxNA?hl=ko&gl=KR&ceid=KR%3Ako 텐아시아 6월 23일
# 초복에 뭐 먹지?｜여성동아 ./articles/CBMiMmh0dHBzOi8vd29tYW4uZG9uZ2EuY29tL0xpYnJhcnkvMy9hbGwvMTIvNDI2NDEyNi8x0gEA?hl=ko&gl=KR&ceid=KR%3Ako 여성동아 3시간 전
# '런닝맨' 냉면 지옥에 빠져버린 '면 요리 특집' ./articles/CBMiS2h0dHBzOi8vd3d3LmVkYWlseS5jby5rci9uZXdzL3JlYWQ_bmV3c0lkPTAyMjQwMjQ2NjM1NjQ0NjcyJm1lZGlhQ29kZU5vPTI1ONIBSGh0dHBzOi8vbS5lZGFpbHkuY28ua3IvYW1wL3JlYWQ_bmV3c0lkPTAyMjQwMjQ2NjM1NjQ0NjcyJm1lZGlhQ29kZU5vPTI1OA?hl=ko&gl=KR&ceid=KR%3Ako 이데일리 6월 23일
# '더워야 팔린다' 한인업소 더위 특수 ./articles/CBMiVGh0dHBzOi8vbmV3cy5rb3JlYWRhaWx5LmNvbS8yMDIzLzA3LzA1L2Vjb25vbXkvZWNvbm9teWdlbmVyYWwvMjAyMzA3MDUyMDIwNTU5NTIuaHRtbNIBAA?hl=ko&gl=KR&ceid=KR%3Ako 미주중앙일보 4일 전
# 7월 여름에 먹어야 제맛, 경기 누들로드 [경기도 가볼만한 곳] ./articles/CBMiL2h0dHBzOi8vd3d3Lmt5ZW9uZ2dpLmNvbS9hcnRpY2xlLzIwMjMwNzA0NTgwMjkz0gEyaHR0cHM6Ly93d3cua3llb25nZ2kuY29tL2FydGljbGVBbXAvMjAyMzA3MDQ1ODAyOTM?hl=ko&gl=KR&ceid=KR%3Ako 경기일보 2일 전
# 5명에 13만원어치 냉면·술 대접…전 인천시의원 벌금형 ./articles/CBMiL2h0dHBzOi8vd3d3LnluYS5jby5rci92aWV3L0FLUjIwMjMwNjI2MTExNDAwMDY10gExaHR0cHM6Ly9tLnluYS5jby5rci9hbXAvdmlldy9BS1IyMDIzMDYyNjExMTQwMDA2NQ?hl=ko&gl=KR&ceid=KR%3Ako 연합뉴스 6월 26일
# [Dining Proposal] 시원한 7월의 외식가 ./articles/CBMiO2h0dHA6Ly93d3cuaG90ZWxyZXN0YXVyYW50LmNvLmtyL25ld3MvYXJ0aWNsZS5odG1sP25vPTEyMzE10gEA?hl=ko&gl=KR&ceid=KR%3Ako 호텔&레스토랑 2일 전
# 박정희-김일성 정상회담 "성사될 뻔 했다"...회담 압박하는 北밀사에 ... ./articles/CBMiPmh0dHA6Ly93d3cud2lraWxlYWtzLWtyLm9yZy9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTQwNDQ10gFBaHR0cDovL3d3dy53aWtpbGVha3Mta3Iub3JnL25ld3MvYXJ0aWNsZVZpZXdBbXAuaHRtbD9pZHhubz0xNDA0NDU?hl=ko&gl=KR&ceid=KR%3Ako 위키리크스한국 어제
# ★'줄리엔강♥' 제이제이 시선 압도하는 S라인 '돈까스에 냉면 먹고시퍼~' ./articles/CBMiOmh0dHBzOi8vd3d3Lmhhbmtvb2tpLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89ODc2MDXSAT1odHRwczovL3d3dy5oYW5rb29raS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTg3NjA1?hl=ko&gl=KR&ceid=KR%3Ako 한국아이닷컴 6월 28일
# [단독] '장제원 아들' 노엘 "배리나", "메갈" 혐오표현 논란 ./articles/CBMiKmh0dHA6Ly93d3cudmlld3NubmV3cy5jb20vYXJ0aWNsZT9xPTIxMjUxNdIBAA?hl=ko&gl=KR&ceid=KR%3Ako 뷰스앤뉴스 2일 전
# "나가기도 무섭다"…호텔 11%·오리고기 9%↑ 천장뚫린 휴가철 물가 ./articles/CBMiM2h0dHBzOi8vd3d3LmFzaWFlLmNvLmtyL2FydGljbGUvMjAyMzA3MTAxMDE2NTA2MjA4MtIBAA?hl=ko&gl=KR&ceid=KR%3Ako 아시아경제 2시간 전
# [인천 30년 지킴이] 인천에 백령도식 냉면 알린 '변가네 옹진냉면' ./articles/CBMiP2h0dHBzOi8vd3d3LmluY2hlb250b2RheS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTIyNTA2NNIBAA?hl=ko&gl=KR&ceid=KR%3Ako 인천투데이 1월 1일
# 증평소방서 이정민 소방사 응급조치로 생명 구조 ./articles/CBMiNGh0dHBzOi8vd3d3LmluZXdzMzY1LmNvbS9uZXdzL2FydGljbGUuaHRtbD9ubz03NzE5MjXSAQA?hl=ko&gl=KR&ceid=KR%3Ako 충북일보 22시간 전
# SSG닷컴, 바캉스 시즌 맞아 대규모 프로모션… “무더위 날릴 시원한 ... ./articles/CBMiLmh0dHBzOi8vd3d3LnNoaW5zZWdhZWdyb3VwbmV3c3Jvb20uY29tLzEwODc3MS_SAQA?hl=ko&gl=KR&ceid=KR%3Ako 신세계그룹 뉴스룸 2시간 전
# 식권 가격 올라도… 직장인들 선택은 '구내식당' ./articles/CBMiPmh0dHBzOi8vd3d3LmtpaG9pbGJvLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0xMDM5MDIz0gEA?hl=ko&gl=KR&ceid=KR%3Ako 기호일보 5일 전
# [금주의 마켓세일] 여름 더위 씻어주는 한인마켓 세일 소식 ._SAQA?hl=ko&gl=KR&ceid=KR%3Ako 애틀랜타 중앙일보 3일 전
# 리정혁 같은 남자, 단짝과 평냉... 요즘 아이들의 통일 위시리스트 ./articles/CBMiRGh0dHBzOi8vd3d3Lm9obXluZXdzLmNvbS9OV1NfV2ViL1ZpZXcvYXRfcGcuYXNweD9DTlROX0NEPUEwMDAyOTQyODIx0gFCaHR0cHM6Ly9tLm9obXluZXdzLmNvbS9OV1NfV2ViL01vYmlsZS9hbXAuYXNweD9DTlROX0NEPUEwMDAyOTQyODIx?hl=ko&gl=KR&ceid=KR%3Ako 오마이뉴스 3일 전
# [인천] 인천정우회(仁川情友會), 2023년도 제4차 정기모임 갖고 화합 ... ./articles/CBMiPGh0dHBzOi8vd3d3LnBvbGljZXR2LmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz00NDkxONIBAA?hl=ko&gl=KR&ceid=KR%3Ako 폴리스TV 6일 전
# 사장님, 저 사실 너무 더워서 반삭했습니다 ./articles/CBMiRGh0dHBzOi8vd3d3Lm9obXluZXdzLmNvbS9OV1NfV2ViL1ZpZXcvYXRfcGcuYXNweD9DTlROX0NEPUEwMDAyOTQxOTcw0gFCaHR0cHM6Ly9tLm9obXluZXdzLmNvbS9OV1NfV2ViL01vYmlsZS9hbXAuYXNweD9DTlROX0NEPUEwMDAyOTQxOTcw?hl=ko&gl=KR&ceid=KR%3Ako 오마이뉴스 2일 전
# 밀가루 쌀 가격 떨어졌는데…식당 밥값은 ‘요지부동’, 왜? ./articles/CBMiKmh0dHBzOi8vd3d3Lm1rLmNvLmtyL25ld3MvZWNvbm9teS8xMDc3OTU2MtIBAA?hl=ko&gl=KR&ceid=KR%3Ako 매일경제 2일 전
# [캐시워크 종합] 5일 오전 10시30분 현재 '신세계푸드 N쇼핑 삼계탕 ... ./articles/CBMiOmh0dHBzOi8vd3d3LmJpenduZXdzLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NjExODbSAQA?hl=ko&gl=KR&ceid=KR%3Ako 비즈월드 4일 전
# SSG닷컴, 휴가철 맞이 대규모 기획전..."시원한 할인" ./articles/CBMiK2h0dHBzOi8vemRuZXQuY28ua3Ivdmlldy8_bm89MjAyMzA3MDcxODQ0MTbSAQA?hl=ko&gl=KR&ceid=KR%3Ako ZD넷 코리아 3일 전
# [세상 돌아보기] 명령으로 되지 않는 경제 ./articles/CBMiP2h0dHA6Ly93d3cuZGFpbHlpbXBhY3QuY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEwMDAwMNIBQmh0dHA6Ly93d3cuZGFpbHlpbXBhY3QuY28ua3IvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTEwMDAwMA?hl=ko&gl=KR&ceid=KR%3Ako 데일리임팩트 5일 전
# 파르나스 호텔 제주 내 중식당 만추안, 여름 보양식 프로모션 진행 ./articles/CBMiRGh0dHBzOi8vd3d3Lndvd3R2LmNvLmtyL05ld3NDZW50ZXIvTmV3cy9SZWFkP2FydGljbGVJZD1BMjAyMzA3MDMwMTQx0gEA?hl=ko&gl=KR&ceid=KR%3Ako 한국경제TV 7일 전
# 박정희, 정상회담 압박 北에 '쇼 않겠다!' 의지 천명 확인 ./articles/CBMiNWh0dHBzOi8vbmV3cy5pbWFlaWwuY29tL3BhZ2Uvdmlldy8yMDIzMDcwOTE3MTUxNjQ2MjEz0gEA?hl=ko&gl=KR&ceid=KR%3Ako 매일신문 19시간 전
# '나혼산' 팜유즈가 다녀간 목포 맛집 4 ./articles/CBMiLmh0dHBzOi8vd3d3MDMuZXNxdWlyZWtvcmVhLmNvLmtyL2FydGljbGUvNzg5NDPSAQA?hl=ko&gl=KR&ceid=KR%3Ako 에스콰이어 5일 전
# 누구나 갈 수 있지만 아무나 못 가는 지리산 화대종주, 초보의 도전 ./articles/CBMiN2h0dHA6Ly9zYW4uY2hvc3VuLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MjI4MDjSAQA?hl=ko&gl=KR&ceid=KR%3Ako 월간산 4일 전
# [시장동향]⑬각종 보양식에 프로모션..초복 D-1 열전 ./articles/CBMiM2h0dHA6Ly93d3cuYml6bmV3cy5vci5rci9uZXdzL2FydGljbGUuaHRtbD9ubz0xNDQyNdIBAA?hl=ko&gl=KR&ceid=KR%3Ako 산업경제뉴스 5시간 전
# 주말쇼핑가이드, "여름 보양식으로 무더운 여름을 이기자" ./articles/CBMiJWh0dHBzOi8vYXRsYW50YWNob3N1bi5jb20vbmV3cy8zOTc3MjfSAQA?hl=ko&gl=KR&ceid=KR%3Ako 주간 동남부 3일 전
# [영상:THISCovery]우크라이나 전쟁이 평양냉면 가격에 미친 영향 ./articles/CBMiQGh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9zb2NpZXR5L3NvY2lldHlfZ2VuZXJhbC8xMDkzNzY2Lmh0bWzSAQA?hl=ko&gl=KR&ceid=KR%3Ako 한겨레 5월 30일
# 냉면당(黨)의 역사는 계속된다 ./articles/CBMiQ2h0dHBzOi8vbS5oZWFsdGguY2hvc3VuLmNvbS9zdmMvbmV3c192aWV3Lmh0bWw_Y29udGlkPTIwMjMwNTMxMDE5OTPSAQA?hl=ko&gl=KR&ceid=KR%3Ako 헬스조선 6월 2일
# 무더위 날려줄 냉면 한 그릇, '이것'은 빼고 드세요 ./articles/CBMiSmh0dHBzOi8vaGVhbHRoLmNob3N1bi5jb20vc2l0ZS9kYXRhL2h0bWxfZGlyLzIwMjMvMDUvMTgvMjAyMzA1MTgwMjM3Ni5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako 헬스조선 5월 18일
# 냉면 이어 비빔밥마저…한 끼 1만원 넘었어요 [그래픽 경제] ./articles/CBMiLmh0dHBzOi8vd3d3LmZubmV3cy5jb20vbmV3cy8yMDIzMDYxNjE3MzY0NTkwNjjSATFodHRwczovL3d3dy5mbm5ld3MuY29tL2FtcE5ld3MvMjAyMzA2MTYxNzM2NDU5MDY4?hl=ko&gl=KR&ceid=KR%3Ako 파이낸셜뉴스 6월 16일
# 김치말이 국수 만들 때 이왕이면 이게 더 좋습니다 ./articles/CBMiRGh0dHBzOi8vd3d3Lm9obXluZXdzLmNvbS9OV1NfV2ViL1ZpZXcvYXRfcGcuYXNweD9DTlROX0NEPUEwMDAyOTQxMjAz0gFCaHR0cHM6Ly9tLm9obXluZXdzLmNvbS9OV1NfV2ViL01vYmlsZS9hbXAuYXNweD9DTlROX0NEPUEwMDAyOTQxMjAz?hl=ko&gl=KR&ceid=KR%3Ako 오마이뉴스 3일 전
# 냉면 1만6000원 시대…업주들 “메밀값 인상 때문에 어쩔 수 없어요” 하소연 ./articles/CBMiJ2h0dHBzOi8vbS5zZWd5ZS5jb20vdmlldy8yMDIzMDQwODUwNzY0MdIBKmh0dHBzOi8vbS5zZWd5ZS5jb20vYW1wVmlldy8yMDIzMDQwODUwNzY0MQ?hl=ko&gl=KR&ceid=KR%3Ako 세계일보 4월 8일
# SSG닷컴, 여름 상품 프로모션 실시 ./articles/CBMiN2h0dHA6Ly93d3cud3NvYmkuY29tL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz0yMDY1MjbSAQA?hl=ko&gl=KR&ceid=KR%3Ako 여성소비자신문 3시간 전
# 한 그릇 만원 넘는 냉면, 건강에는… ./articles/CBMiSmh0dHBzOi8vaGVhbHRoLmNob3N1bi5jb20vc2l0ZS9kYXRhL2h0bWxfZGlyLzIwMjMvMDMvMDYvMjAyMzAzMDYwMTk2NC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako 헬스조선 3월 6일
# 무더위 날려라···SSG닷컴, 바캉스 시즌 시원하게 쏜다 ./articles/CBMiPWh0dHBzOi8vd3d3LnRoZXJlcG9ydC5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89Mzc3MjfSAUBodHRwczovL3d3dy50aGVyZXBvcnQuY28ua3IvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTM3NzI3?hl=ko&gl=KR&ceid=KR%3Ako 더리포트 어제
# [ET] 함흥냉면보다 평양냉면이 더 비싸진 이유…러시아-우크라 전쟁 ... ./articles/CBMiL2h0dHBzOi8vbmV3cy5rYnMuY28ua3IvbmV3cy92aWV3LmRvP25jZD03Njc2ODEz0gEA?hl=ko&gl=KR&ceid=KR%3Ako KBS뉴스 5월 16일
# 경남도, 하절기 대비 다중이용시설 음식점 등 합동점검 ./articles/CBMiOmh0dHA6Ly93d3cubWVkaWFnbi5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTYxODbSAQA?hl=ko&gl=KR&ceid=KR%3Ako 경남미디어 3일 전
# [인천 30년 지킴이] 사계절 생각나는 인천 '황해순모밀냉면' ./articles/CBMiP2h0dHBzOi8vd3d3LmluY2hlb250b2RheS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTIyMDkyMtIBAA?hl=ko&gl=KR&ceid=KR%3Ako 인천투데이 2022. 8. 26.
# '냉면값 1만8000원 말이 된다고 생각하냐?'…선 넘은 냉면에 유재석·화사 '반색' - 서울경제 ./articles/CBMiK2h0dHBzOi8vd3d3LnNlZGFpbHkuY29tL05ld3NWaWV3LzI5TzdMUUpBRk_SASxodHRwczovL20uc2VkYWlseS5jb20vTmV3c1ZpZXdBbXAvMjlPN0xRSkFGTw?hl=ko&gl=KR&ceid=KR%3Ako 서울경제신문 4월 7일
# 위메프, 초복 앞두고 여름 보양 간편식 매출↑ ./articles/CBMiO2h0dHBzOi8vd3d3Lm5nZXRuZXdzLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NDIwMjIy0gEA?hl=ko&gl=KR&ceid=KR%3Ako 뉴스저널리즘 6일 전
# 대상, 전국 3대 냉면 '진주식 비빔냉면' 출시 ./articles/CBMiOmh0dHBzOi8vd3d3LmFtbmV3cy5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NTM1ODfSAQA?hl=ko&gl=KR&ceid=KR%3Ako 농축유통신문 5월 10일
# 장마철 집 나간 입맛, 시큼하게 찾아드립니다 ./articles/CBMiRGh0dHBzOi8vd3d3Lm9obXluZXdzLmNvbS9OV1NfV2ViL1ZpZXcvYXRfcGcuYXNweD9DTlROX0NEPUEwMDAyOTQzMDg40gFCaHR0cHM6Ly9tLm9obXluZXdzLmNvbS9OV1NfV2ViL01vYmlsZS9hbXAuYXNweD9DTlROX0NEPUEwMDAyOTQzMDg4?hl=ko&gl=KR&ceid=KR%3Ako 오마이뉴스 어제
# 평화의 상징 '평양냉면', 남북이 어떻게 다른가? ./articles/CBMiPmh0dHBzOi8vaDIxLmhhbmkuY28ua3IvYXJ0aS9jdWx0dXJlL2N1bHR1cmVfZ2VuZXJhbC81MzE5Ni5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako 한겨레21 1월 13일
# 북 “평양냉면, 유네스코 무형문화유산 됐다” ./articles/CBMiO2h0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9wb2xpdGljcy9kaXBsb21hY3kvMTA3MDEwNS5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako 한겨레 2022. 12. 4.
# 30년 노하우 담은 '대들보 불고기 냉면' ./articles/CBMiOGh0dHA6Ly93d3cuaWRqbmV3cy5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTM4MTc00gEA?hl=ko&gl=KR&ceid=KR%3Ako 당진신문 2월 18일
# 식당서 한그릇 1만원 넘자 '집냉면' 인기 ./articles/CBMiL2h0dHBzOi8vbS5la24ua3Ivdmlldy5waHA_a2V5PTIwMjMwNjAxMDEwMDAwMDg00gEA?hl=ko&gl=KR&ceid=KR%3Ako 에너지경제 6월 1일
# 수원시 권선구 세류3동 지역사회보장협의체, 음식만들기 프로그램 ... ./articles/CBMiP2h0dHA6Ly93d3cubW9udGhseXBlb3BsZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTU5NDkxMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako 월간인물 3일 전
# 냉면, 비빔밥… 1만원으로 먹을 게 없는 야속한 시절 ./articles/CBMiPGh0dHBzOi8vd3d3LnRoZXNjb29wLmNvLmtyL25ld3MvYXJ0aWNsZVZpZXcuaHRtbD9pZHhubz01NzU4M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako 더스쿠프 4월 27일
# 풀무원 '냉면 밀키트' 2종 출시 ./articles/CBMiMGh0dHBzOi8vd3d3Lm5ld3NwaW0uY29tL25ld3Mvdmlldy8yMDIzMDUxNTAwMDMyMdIBMWh0dHBzOi8vbS5uZXdzcGltLmNvbS9uZXdzYW1wL3ZpZXcvMjAyMzA1MTUwMDAzMjE?hl=ko&gl=KR&ceid=KR%3Ako 뉴스핌 5월 15일
# [진솔 국밥] “유명한 진솔 국밥 OC 왔어요” - 미주 한국일보 ./articles/CBMiMmh0dHA6Ly93d3cua29yZWF0aW1lcy5jb20vYXJ0aWNsZS8yMDIzMDcwMy8xNDcxODM50gEA?hl=ko&gl=KR&ceid=KR%3Ako 미주 한국일보 6일 전
# SPC삼립, 하이면 냉면 3종 출시 ./articles/CBMiMGh0dHBzOi8vd3d3Lm5ld3NwaW0uY29tL25ld3Mvdmlldy8yMDIzMDQxMjAwMDA2MdIBMWh0dHBzOi8vbS5uZXdzcGltLmNvbS9uZXdzYW1wL3ZpZXcvMjAyMzA0MTIwMDAwNjE?hl=ko&gl=KR&ceid=KR%3Ako 뉴스핌 4월 12일
# 北 '평양냉면풍습' 유네스코 등록..."세상에 자랑할만한 민족 유산" ./articles/CBMiOmh0dHBzOi8vd3d3LnNwbmV3cy5jby5rci9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89NTk0ODnSAQA?hl=ko&gl=KR&ceid=KR%3Ako SPN 서울평양뉴스 2022. 12. 18.
# [불의 물방울] ⑥ 호르몬야키와 '푸른 도깨비' ./articles/CBMiQWh0dHBzOi8vd3d3LnNvbW1lbGllcnRpbWVzLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTI1MDA10gEA?hl=ko&gl=KR&ceid=KR%3Ako 소믈리에타임즈 4일 전
# "풀무원 냉면 맛없으면 돈 100% 돌려줍니다" ./articles/CBMiK2h0dHBzOi8vemRuZXQuY28ua3Ivdmlldy8_bm89MjAyMzA1MjIwODI4NTfSAQA?hl=ko&gl=KR&ceid=KR%3Ako ZD넷 코리아 5월 22일
# 한그릇 2만원 시대 '눈앞'…냉면 가격이 뜨거워졌다 - 서울경제 ./articles/CBMiK2h0dHBzOi8vd3d3LnNlZGFpbHkuY29tL05ld3NWaWV3LzI5TzVRVjlDRjbSASxodHRwczovL20uc2VkYWlseS5jb20vTmV3c1ZpZXdBbXAvMjlPNVFWOUNGNg?hl=ko&gl=KR&ceid=KR%3Ako 서울경제신문 4월 3일
# [대놓고PPL] 인천 냉면 마니아들의 성지 '황해순모밀냉면' ./articles/CBMiP2h0dHBzOi8vd3d3LmluY2hlb250b2RheS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTIyMDU2MNIBAA?hl=ko&gl=KR&ceid=KR%3Ako 인천투데이 2022. 8. 10.
# 외식의 계절 여름…"이제는 냉면 한 그릇도 겁나요" ./articles/CBMiNmh0dHBzOi8vbS55b25oYXBuZXdzdHYuY28ua3IvbmV3cy9NWUgyMDIzMDYwNDAwMTgwMDY0MdIBAA?hl=ko&gl=KR&ceid=KR%3Ako 연합뉴스TV 6월 4일
# 단팥빵 4500원·냉면 18000원…'사장'도 손님도 '못 살겠슈' - 서울경제 ./articles/CBMiK2h0dHBzOi8vd3d3LnNlZGFpbHkuY29tL05ld3NWaWV3LzI5Tzc1NERROTDSASxodHRwczovL20uc2VkYWlseS5jb20vTmV3c1ZpZXdBbXAvMjlPNzU0RFE5MA?hl=ko&gl=KR&ceid=KR%3Ako 서울경제신문 4월 6일
# “31일 밤 12시 '얼죽냉' 외치며 새해 맞이 어때요” ./articles/CBMiQGh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9zb2NpZXR5L3NvY2lldHlfZ2VuZXJhbC8xMDcyNjI5Lmh0bWzSAQA?hl=ko&gl=KR&ceid=KR%3Ako 한겨레 2022. 12. 21.
# 농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업 ./articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako The Guru (더 구루) 3월 23일
# 테프나라, '메밀에 빠진 테프냉면' 신제품 출시 ./articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako 전민일보 5월 30일
# 동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ... ./articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako 한국강사신문 5월 13일
# "삼겹살 2인분에 냉면 주세요"…계산서에 찍힌 금액은 ./articles/CBMiP2h0dHBzOi8vd3d3LmluY2hlb25pbGJvLmNvbS9uZXdzL2FydGljbGVWaWV3Lmh0bWw_aWR4bm89MTE5MDUyM9IBAA?hl=ko&gl=KR&ceid=KR%3Ako 인천일보 4월 19일

# %%
# 검색결과를 list 형태로 받고 기사 하나당 딕셔너리 구조로 받고싶음
# [ {"title":"파이선 미래", "link":"~~~", "writer":"한국경제신물", "date":"어제"},{},{}... ]

# 딕셔너리 선언 : news_item = {}
# 딕셔너리 내용 추가 : key, value 추가, news_item["title"] = "파이썬 미래"

# 리스트 선언 : news = []
# 리스트 추가 : append()
news_item={}
news = []

keyword = input("검색어 입력")

url = "https://news.google.com/search?q="+keyword+"&hl=ko&gl=KR&ceid=KR%3Ako"

res = requests.get(url)
soup = BeautifulSoup(res.text,"lxml")

# 화면에 보이는 모든 article 가져오기
articles = soup.select("div.xrnccd article")
for article in articles:    
    # 제목    
    news_item["title"] = article.h3.string
    # 링크
    news_item["link"] = article.a["href"]
    # 작성자 
    news_item["writer"] = article.img.get("alt")
    # 작성날짜 
    news_item["date"] = article.time.string
    
    news.append(news_item)
    print(news)
    # print(title, link, writer, date)
# Out:
# [{'title': '[영상:THISCovery] 스타벅스 경동1960점 가면 매운맛 냉면은 필수!', 'link': './articles/CBMiQGh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9zb2NpZXR5L3NvY2lldHlfZ2VuZXJhbC8xMDk4NTc5Lmh0bWzSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한겨레', 'date': '6일 전'}]
# [{'title': '너무 비싼 평양냉면, 그런데 그만 빠져버렸습니다', 'link': './articles/CBMiRGh0dHBzOi8vd3d3Lm9obXluZXdzLmNvbS9OV1NfV2ViL1ZpZXcvYXRfcGcuYXNweD9DTlROX0NEPUEwMDAyOTQxODk20gFCaHR0cHM6Ly9tLm9obXluZXdzLmNvbS9OV1NfV2ViL01vYmlsZS9hbXAuYXNweD9DTlROX0NEPUEwMDAyOTQxODk2?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '오마이뉴스', 'date': '2일 전'}, {'title': '너무 비싼 평양냉면, 그런데 그만 빠져버렸습니다', 'link': './articles/CBMiRGh0dHBzOi8vd3d3Lm9obXluZXdzLmNvbS9OV1NfV2ViL1ZpZXcvYXRfcGcuYXNweD9DTlROX0NEPUEwMDAyOTQxODk20gFCaHR0cHM6Ly9tLm9obXluZXdzLmNvbS9OV1NfV2ViL01vYmlsZS9hbXAuYXNweD9DTlROX0NEPUEwMDAyOTQxODk2?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '오마이뉴스', 'date': '2일 전'}]
# [{'title': "올여름 냉면 가격이 '오싹'…유명 맛집은 1만5천원도 우습지", 'link': './articles/CBMiOWh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9lY29ub215L2NvbnN1bWVyLzEwOTY1MTAuaHRtbNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한겨레', 'date': '6월 19일'}, {'title': "올여름 냉면 가격이 '오싹'…유명 맛집은 1만5천원도 우습지", 'link': './articles/CBMiOWh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9lY29ub215L2NvbnN1bWVyLzEwOTY1MTAuaHRtbNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한겨레', 'date': '6월 19일'}, {'title': "올여름 냉면 가격이 '오싹'…유명 맛집은 1만5천원도 우습지", 'link': './articles/CBMiOWh0dHBzOi8vd3d3LmhhbmkuY28ua3IvYXJ0aS9lY29ub215L2NvbnN1bWVyLzEwOTY1MTAuaHRtbNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한겨레', 'date': '6월 19일'}]
# [{'title': "연수구, 지역 어르신 위한 후원물품 '사랑의 냉면' 전달 받아", 'link': './articles/CBMiOGh0dHA6Ly93d3cueWVvbnN1LmluZm8vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTQ1MzI20gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '연수신문', 'date': '4일 전'}, {'title': "연수구, 지역 어르신 위한 후원물품 '사랑의 냉면' 전달 받아", 'link': './articles/CBMiOGh0dHA6Ly93d3cueWVvbnN1LmluZm8vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTQ1MzI20gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '연수신문', 'date': '4일 전'}, {'title': "연수구, 지역 어르신 위한 후원물품 '사랑의 냉면' 전달 받아", 'link': './articles/CBMiOGh0dHA6Ly93d3cueWVvbnN1LmluZm8vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTQ1MzI20gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '연수신문', 'date': '4일 전'}, {'title': "연수구, 지역 어르신 위한 후원물품 '사랑의 냉면' 전달 받아", 'link': './articles/CBMiOGh0dHA6Ly93d3cueWVvbnN1LmluZm8vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTQ1MzI20gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '연수신문', 'date': '4일 전'}]
# [{'title': '"평양냉면의 시대가 오기를 기다렸다." 육수로 승부수 던진 김태현 벽제 ...', 'link': './articles/CBMiOWh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTYwMzY5N9IBPGh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTYwMzY5Nw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '블로터', 'date': '1시간 전'}, {'title': '"평양냉면의 시대가 오기를 기다렸다." 육수로 승부수 던진 김태현 벽제 ...', 'link': './articles/CBMiOWh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTYwMzY5N9IBPGh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTYwMzY5Nw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '블로터', 'date': '1시간 전'}, {'title': '"평양냉면의 시대가 오기를 기다렸다." 육수로 승부수 던진 김태현 벽제 ...', 'link': './articles/CBMiOWh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTYwMzY5N9IBPGh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTYwMzY5Nw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '블로터', 'date': '1시간 전'}, {'title': '"평양냉면의 시대가 오기를 기다렸다." 육수로 승부수 던진 김태현 벽제 ...', 'link': './articles/CBMiOWh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTYwMzY5N9IBPGh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTYwMzY5Nw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '블로터', 'date': '1시간 전'}, {'title': '"평양냉면의 시대가 오기를 기다렸다." 육수로 승부수 던진 김태현 벽제 ...', 'link': './articles/CBMiOWh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTYwMzY5N9IBPGh0dHBzOi8vd3d3LmJsb3Rlci5uZXQvbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTYwMzY5Nw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '블로터', 'date': '1시간 전'}]
# [{'title': "'생활의달인' 은둔식달–평양냉면·밀면, 의정부 도시락 아빠, 상위 1 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyOTUxONIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 26일'}, {'title': "'생활의달인' 은둔식달–평양냉면·밀면, 의정부 도시락 아빠, 상위 1 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyOTUxONIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 26일'}, {'title': "'생활의달인' 은둔식달–평양냉면·밀면, 의정부 도시락 아빠, 상위 1 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyOTUxONIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 26일'}, {'title': "'생활의달인' 은둔식달–평양냉면·밀면, 의정부 도시락 아빠, 상위 1 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyOTUxONIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 26일'}, {'title': "'생활의달인' 은둔식달–평양냉면·밀면, 의정부 도시락 아빠, 상위 1 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyOTUxONIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 26일'}, {'title': "'생활의달인' 은둔식달–평양냉면·밀면, 의정부 도시락 아빠, 상위 1 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyOTUxONIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 26일'}]
# [{'title': '[이거야!ONE] 남북 정상 만날 때 마다 평양냉면 먹는 이유?', 'link': './articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNl8yMDIzMDYzMDE5MTg0Njk1NzfSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDZfMjAyMzA2MzAxOTE4NDY5NTc3?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'YTN', 'date': '6월 30일'}, {'title': '[이거야!ONE] 남북 정상 만날 때 마다 평양냉면 먹는 이유?', 'link': './articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNl8yMDIzMDYzMDE5MTg0Njk1NzfSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDZfMjAyMzA2MzAxOTE4NDY5NTc3?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'YTN', 'date': '6월 30일'}, {'title': '[이거야!ONE] 남북 정상 만날 때 마다 평양냉면 먹는 이유?', 'link': './articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNl8yMDIzMDYzMDE5MTg0Njk1NzfSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDZfMjAyMzA2MzAxOTE4NDY5NTc3?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'YTN', 'date': '6월 30일'}, {'title': '[이거야!ONE] 남북 정상 만날 때 마다 평양냉면 먹는 이유?', 'link': './articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNl8yMDIzMDYzMDE5MTg0Njk1NzfSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDZfMjAyMzA2MzAxOTE4NDY5NTc3?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'YTN', 'date': '6월 30일'}, {'title': '[이거야!ONE] 남북 정상 만날 때 마다 평양냉면 먹는 이유?', 'link': './articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNl8yMDIzMDYzMDE5MTg0Njk1NzfSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDZfMjAyMzA2MzAxOTE4NDY5NTc3?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'YTN', 'date': '6월 30일'}, {'title': '[이거야!ONE] 남북 정상 만날 때 마다 평양냉면 먹는 이유?', 'link': './articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNl8yMDIzMDYzMDE5MTg0Njk1NzfSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDZfMjAyMzA2MzAxOTE4NDY5NTc3?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'YTN', 'date': '6월 30일'}, {'title': '[이거야!ONE] 남북 정상 만날 때 마다 평양냉면 먹는 이유?', 'link': './articles/CBMiMWh0dHBzOi8vd3d3Lnl0bi5jby5rci9fbG4vMDEwNl8yMDIzMDYzMDE5MTg0Njk1NzfSAUNodHRwczovL20ueXRuLmNvLmtyL25ld3Nfdmlldy5hbXAucGhwP3BhcmFtPTAxMDZfMjAyMzA2MzAxOTE4NDY5NTc3?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'YTN', 'date': '6월 30일'}]
# [{'title': '맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는…', 'link': './articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'news.kmib.co.kr', 'date': '6월 18일'}, {'title': '맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는…', 'link': './articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'news.kmib.co.kr', 'date': '6월 18일'}, {'title': '맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는…', 'link': './articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'news.kmib.co.kr', 'date': '6월 18일'}, {'title': '맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는…', 'link': './articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'news.kmib.co.kr', 'date': '6월 18일'}, {'title': '맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는…', 'link': './articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'news.kmib.co.kr', 'date': '6월 18일'}, {'title': '맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는…', 'link': './articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'news.kmib.co.kr', 'date': '6월 18일'}, {'title': '맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는…', 'link': './articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'news.kmib.co.kr', 'date': '6월 18일'}, {'title': '맵단짠의 정석 간편식 ‘비빔냉면’ 왕좌에는…', 'link': './articles/CBMiT2h0dHA6Ly9uZXdzLmttaWIuY28ua3IvYXJ0aWNsZS92aWV3LmFzcD9hcmNpZD0wMDE4MzY3MDQzJmNvZGU9NjExNzE4MTEmc2lkMT1jZW7SATJodHRwczovL20ua21pYi5jby5rci92aWV3X2FtcC5hc3A_YXJjaWQ9MDAxODM2NzA0Mw?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'news.kmib.co.kr', 'date': '6월 18일'}]
# [{'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}, {'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}, {'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}, {'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}, {'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}, {'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}, {'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}, {'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}, {'title': '"배 타고 왕복 8시간..\'냉면 킬러\'의 전국 평양냉면 탐방기"', 'link': './articles/CBMiKGh0dHBzOi8vd3d3Lm5vY3V0bmV3cy5jby5rci9uZXdzLzU5NjUwNDDSASpodHRwczovL20ubm9jdXRuZXdzLmNvLmtyL25ld3MvYW1wLzU5NjUwNDA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노컷뉴스', 'date': '6월 24일'}]
# [{'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}, {'title': '슴슴한 맛이 당길 때, 평양냉면', 'link': './articles/CBMiP2h0dHBzOi8vd3d3Lm5vYmxlc3NlLmNvbS9ob21lL25ld3MvbWFnYXppbmUvZGV0YWlsLnBocD9ubz0xMjc0OdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '노블레스닷컴', 'date': '6월 9일'}]
# [{'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}, {'title': '[화제의 맛] 올 여름 다양한 냉면이 온다', 'link': './articles/CBMiNGh0dHA6Ly93d3cuZm9vZG5ld3MubmV3cy9uZXdzL2FydGljbGUuaHRtbD9ubz04MDQ0OTnSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '식품외식경영', 'date': '6월 27일'}]
# [{'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}, {'title': '삼계탕‧냉면 1만5000원 육박에도…자영업 40% "3년내 폐업 고려"', 'link': './articles/CBMiMWh0dHBzOi8vd3d3LmFzaWF0aW1lLmNvLmtyL2FydGljbGUvMjAyMzA3MDI1MDAwMzbSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '아시아타임즈', 'date': '7일 전'}]
# [{'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}, {'title': "[영국의 탈북민들] ⑤ 뉴몰든의 '평양냉면'", 'link': './articles/CBMiSmh0dHBzOi8vd3d3LnJmYS5vcmcva29yZWFuL3NwZWNpYWwtcHJvZ3JhbXMvdWtkZWZlY3Rvci0wNjIwMjAyMzEzNDAxOC5odG1s0gEA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '자유아시아방송', 'date': '6월 20일'}]
# [{'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8vbmV3cy5tdC5jby5rci9tdHZpZXcucGhwP25vPTIwMjMwNjI4MDkxOTU0NDk4NjjSAT1odHRwczovL20ubXQuY28ua3IvcmVuZXcvdmlld19hbXAuaHRtbD9ubz0yMDIzMDYyODA5MTk1NDQ5ODY4?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '머니투데이', 'date': '6월 28일'}, {'title': '삼계탕 1만6000원·냉면 1만1000원…올 여름 외식 유독 버겁네', 'link': './articles/CBMiN2h0dHBzOi8 ...
# [{'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlld0FtcC5odG1sP2lkeG5vPTMwMTA1Mg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '시사저널e', 'date': '9일 전'}, {'title': '평양냉면 같은 국산 맥주의 매력···오비맥주, 비어마스터클래스 들어보니', 'link': './articles/CBMiP2h0dHA6Ly93d3cuc2lzYWpvdXJuYWwtZS5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTMwMTA1MtIBQmh0dH ...
# [{'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}, {'title': "풀무원 '고메밀물냉면' 내세워 中 홀린다", 'link': './articles/CBMiNmh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbW9iaWxlL2FydGljbGUuaHRtbD9ubz01NTQ0N9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '6월 19일'}]
# [{'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '동아일보', 'date': '6일 전'}, {'title': '식혜·냉면·빙수…여름철 휴가지 음식점 4100곳 ‘집중 위생점검’ 실시', 'link': './articles/CBMiRGh0dHBzOi8vd3d3LmRvbmdhLmNvbS9uZXdzL1BvbGl0aWNzL2FydGljbGUvYWxsLzIwMjMwNzA0LzEyMDA2NTI2OS8y0gE3aHR0cHM6Ly93d3cuZG9uZ2EuY29tL25ld3MvYW1wL2FsbC8yMDIzMDcwNC8xMjAwNjUyNjkvMg?hl=ko&gl=KR&ceid=KR%3Ako', 'wri ...
# [{'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}, {'title': '여름 대표 메뉴 삼계탕·냉면 가격 들썩', 'link': './articles/CBMiNmh0dHBzOi8vd3d3Lmt3bmV3cy5jby5rci9wYWdlL3ZpZXcvMjAyMzA2MTQxNjU3NDEzODU2M9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '강원일보', 'date': '6월 15일'}]
# [{'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '6월 12일'}, {'title': "'생활의 달인' 은둔식달–비빔국수·평양냉면, 일본 원조 소금빵, 숨은 ...", 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyODQyN9IBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': ...
# ...
# [{'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './articles/CBMiNGh0dHBzOi8vd3d3LnRoZWd1cnUuY28ua3IvbmV3cy9hcnRpY2xlLmh0bWw_bm89NTE0MTTSAQA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': 'The Guru (더 구루)', 'date': '3월 23일'}, {'title': "농심, 日서 '마시는 후루루 냉면' 출시…이토엔과 협업", 'link': './ar ...
# [{'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTM3OTEyMNIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '전민일보', 'date': '5월 30일'}, {'title': "테프나라, '메밀에 빠진 테프냉면' 신제품 출시", 'link': './articles/CBMiPGh0dHBzOi8vd3d3Lmplb25taW4uY28ua3IvbmV3cy9hcnRpY2xlVmlldy5odG1sP ...
# [{'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR%3Ako', 'writer': '한국강사신문', 'date': '5월 13일'}, {'title': '동네 한 바퀴, 46년 전통 냉면집부터 600년 고택의 다과까지…이만기 ...', 'link': './articles/CBMiP2h0dHBzOi8vd3d3LmxlY3R1cmVybmV3cy5jb20vbmV3cy9hcnRpY2xlVmlldy5odG1sP2lkeG5vPTEyNTk1NdIBAA?hl=ko&gl=KR&ceid=KR ...

# %%
# 다나와

# https://www.danawa.com/
# 로그인 : https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F
from fake_useragent import UserAgent

form_data = {
    "redirectUrl": "https://www.danawa.com/", 
    "loginMemberType": "general",
    "id": "rkdtjdduq88",
    "isSaveId": "true",
    "password": "dutajrdj123@@@"
}

headers = {
    "user-agent":UserAgent().chrome,
    "Referer" : "https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F"
}

with requests.Session() as s:
    # 로그인한것처럼 시도
    res = s.post("https://auth.danawa.com/login",form_data,headers=headers)

    # print(res.text)
    res = s.get("https://buyer.danawa.com/order/Order/orderList", headers=headers)

    soup = BeautifulSoup(res.text, "lxml")

    # id 를 가지고 있는 p 태그 찾기
    check_id = soup.find("p", class_="user")
    print(check_id)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File c:\source\pythonsource\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\source\pythonsource\Lib\site-packages\urllib3\connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#
# File c:\source\pythonsource\Lib\site-packages\urllib3\connection.py:635, in HTTPSConnection.connect(self)
#     627     warnings.warn(
#     628         (
#     629             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     632         SystemTimeWarning,
#     633     )
# --> 635 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     636     sock=sock,
#     637     cert_reqs=self.cert_reqs,
#     638     ssl_version=self.ssl_version,
#     639     ssl_minimum_version=self.ssl_minimum_version,
#     640     ssl_maximum_version=self.ssl_maximum_version,
#     641     ca_certs=self.ca_certs,
#     642     ca_cert_dir=self.ca_cert_dir,
#     643     ca_cert_data=self.ca_cert_data,
#     644     cert_file=self.cert_file,
#     645     key_file=self.key_file,
#     646     key_password=self.key_password,
#     647     server_hostname=server_hostname,
#     648     ssl_context=self.ssl_context,
#     649     tls_in_tls=tls_in_tls,
#     650     assert_hostname=self.assert_hostname,
#     651     assert_fingerprint=self.assert_fingerprint,
#     652 )
#     653 self.sock = sock_and_verified.socket
#
# File c:\source\pythonsource\Lib\site-packages\urllib3\connection.py:776, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     774         server_hostname = normalized
# --> 776 ssl_sock = ssl_wrap_socket(
#     777     sock=sock,
#     778     keyfile=key_file,
#     779     certfile=cert_file,
#     780     key_password=key_password,
#     781     ca_certs=ca_certs,
#     782     ca_cert_dir=ca_cert_dir,
#     783     ca_cert_data=ca_cert_data,
#     784     server_hostname=server_hostname,
#     785     ssl_context=context,
#     786     tls_in_tls=tls_in_tls,
#     787 )
#     789 try:
#
# File c:\source\pythonsource\Lib\site-packages\urllib3\util\ssl_.py:466, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     464     pass
# --> 466 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     467 return ssl_sock
#
# File c:\source\pythonsource\Lib\site-packages\urllib3\util\ssl_.py:510, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     508     return SSLTransport(sock, ssl_context, server_hostname)
# --> 510 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#
# SSLError: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1002)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File c:\source\pythonsource\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#
# File c:\source\pythonsource\Lib\site-packages\urllib3\connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# SSLError: [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1002)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\source\pythonsource\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\source\pythonsource\Lib\site-packages\urllib3\connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#
# File c:\source\pythonsource\Lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='buyer.danawa.com', port=443): Max retries exceeded with url: /order/Order/orderList (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1002)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Cell In[7], line 25
#      22 res = s.post("https://auth.danawa.com/login",form_data,headers=headers)
#      24 # print(res.text)
# ---> 25 res = s.get("https://buyer.danawa.com/order/Order/orderList", headers=headers)
#      27 soup = BeautifulSoup(res.text, "lxml")
#      29 # id 를 가지고 있는 p 태그 찾기
#
# File c:\source\pythonsource\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\source\pythonsource\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\source\pythonsource\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\source\pythonsource\Lib\site-packages\requests\adapters.py:517, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     513         raise ProxyError(e, request=request)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
# --> 517         raise SSLError(e, request=request)
#     519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='buyer.danawa.com', port=443): Max retries exceeded with url: /order/Order/orderList (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:1002)')))

# %%
# 네이버 오픈 api + 엑셀 저장
from openpyxl import Workbook

wb = Workbook() 
# 활성화 시트 가져오기
ws = wb.active
ws.title = "iphone"

# 특정 열 너비 조절
ws.column_dimensions["B"].width = 100
ws.column_dimensions["C"].width = 70

# 타이틀 행 삽입
ws.append(["순위","상품명","상세주소"])

headers = {
    "X-Naver-Client-Id": "9tvbl4_5W_kZ82llVJMn",
    "X-Naver-Client-Secret": "gY_G1ehcqt",
}


url = "https://openapi.naver.com/v1/search/shop.json"

# https://openapi.naver.com/v1/search/shop.json?query=아이폰&display=100&start=1

start, num = 1, 0

for idx in range(10):
    # 1, 101, 201, 301....
    start_num = start + (idx * 100)

    params = {
        "query" : "아이폰",
        "display":"100",
        "start": str(start_num),

    }
    
    res = requests.get(url, params=params, headers=headers)

    # print(res.url)

    data = res.json()

    for item in data['items']:
        num +=1
        # print(num, item['title'], item['link'])
        ws.append([num, item['title'], item['link']])
        ws.cell(row=num, column=3).hyperlink = item['link']

wb.save("naver.xlsx")
wb.close()

# %%
from openpyxl import Workbook

wb = Workbook()  # 워크북 객체 생성

wb.save("naver.xlsx")
wb.close()

# %%
# isbn, title, discount, publisher
# naver open api - book(book.xlsx)

import requests
from openpyxl import Workbook

wb = Workbook()
ws = wb.active
ws.title = "book"

ws.append(["번호","isbn","도서명","가격","출판사"])

# 특정 열 너비 조절
ws.column_dimensions["B"].width = 30 # isbn
ws.column_dimensions["C"].width = 70 # title
ws.column_dimensions["D"].width = 20 # discount
ws.column_dimensions["E"].width = 20 # publisher

headers = {
    "X-Naver-Client-Id": "9tvbl4_5W_kZ82llVJMn",
    "X-Naver-Client-Secret": "gY_G1ehcqt",
}

url = "https://openapi.naver.com/v1/search/book.json"

start, num = 1, 0

for idx in range(2):
    # 1, 101, 201, 301....
    start_num = start + (idx * 100)

    params = {
        "query" : "베르나르 베르베르",
        "display":"100",
        "start": str(start_num),

    }
    
    res = requests.get(url, params=params, headers=headers)

    # print(res.url)

    data = res.json()

    for item in data['items']:
        num +=1        
        ws.append([num, item['isbn'],item['title'],item['discount'],item['publisher']])

wb.save("book.xlsx")
wb.close()

# %%
import requests
from bs4 import BeautifulSoup

# gmarket best - 컴퓨터/전자 카테고리
# https://www.gmarket.co.kr/n/best?viewType=G&groupCode=G06

# 상품명, 가격
url = "https://www.gmarket.co.kr/n/best?viewType=G&groupCode=G06"

res = requests.get(url)

soup = BeautifulSoup(res.text,"html.parser")

best_list = soup.select("div.best-list li")

# enumerate(리스트)

for idx,item in enumerate(best_list,start=1):
    # 상품명
    product_name = item.select_one("a.itemname").string
    # 가격
    product_price = item.select_one("div.s-price > strong span").get_text()
    
    print(idx,product_name,product_price)
# Out:
# 1 [Lenovo]태블릿 p12 샤오신패드 2022 pad 2022 6+128G 10.6인치 WIFI 중국내수용 172,800원
# 2 [Lenovo]레노버 P12 XiaoxinPad 2022 태블릿 PC 테블릿 4+128G 중국내수용 154,000원
# 3 [르젠]르젠 앱연동 스마트 BLDC 리모컨 선풍기 LZEF-DC02 71,160원
# 4 [대우](혜택가 3.5만원) 2023년형 대우 3단 높이조절 리모컨 34cm형 써큘레이터 선풍기 / DEF-KC3040 서큘레이터 39,900원
# 5 [숲속바람]Forest Wind 저소음 5엽 스탠드 선풍기 33,510원
# 6 [삼성전자]삼성 비스포크 제트 무선청소기 풀패키지 VS20B957F5E 220W 산토리니베이지 798,000원
# 7 [신일전자]2023 NEW 신일 BLDC 에어서큘레이터 S9 베이지(SIF-CS30BG) 132,000원
# 8 [윈드피아]가정용 업소용 스탠드 리모컨 선풍기 인기상품 1700R 39,900원
# 9 [로지텍](빠른직구) 로지텍 MX Master 3S 블루투스 무선 마우스 미개봉 정품 재고보유 105,900원
# 10 [코드나인]탁상용 휴대용 선풍기_FAN190 /화이트+화이트 36,600원
# 11 [쿠쿠](혜택가 5.9만원) 쿠쿠 본사직영 20L 전자레인지 CMW-A201DW 67,510원
# 12 [DELL]E2722HS 27인치 FHD IPS 16:9 VESA HDMI DP VGA 내장스피커 델 모니터 3년 무상 (주문 폭주 출고 지연) 179,000원
# 13 [케어프린]자동 무선 멀티 야채 이유식 다지기 믹서기 600ml 46,800원
# 14 [대웅]대웅 가정용 스탠드선풍기  키높이선풍기 29,800원
# 15 맥심 화이트골드 170티 x6개입 총1020티 134,100원
# 16 [SK매직]SK매직 써큘레이터 FAN-CS1000MGR 무소음 써큘레이터 빈티지 그레이 71,890원
# 17 [에버홈]에버홈 글라스텐 파워 멀티 믹서기 EV-MC7000 59,800원
# 18 [Callia]갤럭시 C타입 휴대용 미니 18W 고속 충전 핸드폰 보조배터리 5000mAh 32,800원
# 19 [테팔]테팔 믹서기 블렌더 블렌드포스 플러스 BL4258KR BL4258 블랙 45,510원
# 20 [위닉스]공식인증점)위닉스 17L제습기 {DN3E170-LWK} 1등급 제습기 415,000원
# 21 [위닉스]공식인증점) 위닉스 제습기 12L {DXTE120-MPK} 2023년 신상품 265,000원
# 22 [아이닉]대용량 스텐 에어프라이어 16L 화이트 블랙 스카이블루 (+10만원 상당 조리도구7종) 179,000원
# 23 [쿠쿠](혜택가 7.4만원) 쿠쿠 본사직영 스피드팟 멀티쿠커 CMC-A0655FB 89,100원
# 24 [공식파트너] 위닉스 뽀송 제습기 10L DXAE100-JWK 231,830원
# 25 [대우](혜택가 2.9만원) 2023년형 대우 3단 높이조절 34cm형 써큘레이터 선풍기 / DEF-KC2030 서큘레이터 33,300원
# 26 [신일전자]신일 BLDC 무소음 리모컨 선풍기 SIF-DC826 129,900원
# 27 [엘지전자(가전)]  [1등급/20L] LG 휘센 오브제 듀얼 인버터 제습기 베이지[DQ2 639,150원
# 28 [테팔]테팔 믹서기 블렌더 블렌데오 플러스 BL2C01 34,900원
# 29 [르젠]르젠 스탠드형 리모컨 써큘레이터 선풍기 LZEF-AR03 47,310원
# 30 [샤오미]샤오미 미지아 무선 선풍기 5세대 에어서큘레이터 BLDC 마그네틱 충전 돼지코 증정 BPLDS05DM 106,900원
# 31 [로지텍]로지텍코리아 정품 기계식 유선 키보드 K835 TKL 64,910원
# 32 1+1 탁상용 휴대용 선풍기_FAN190 /화이트+그레이 36,600원
# 33 [넥스코]넥스코 32단 스텐딩 12인치 써큘레이터 BLDC NKF-3290G 79,000원
# 34 [신일전자]2023년 NEW  BLDC 서큘레이터 air S9 베이지/딥그린/블루(SIF-CS30BG 131,040원
# 35 [쿠쿠](혜택가 22.8만원) 쿠쿠 본사직영 CRP-CHP1010FD 10인용 IH전기압력 밥솥 260,110원
# 36 [까사맘]까사맘 음식물 쓰레기 냉장고 처리기 3.5L CAA-601 65,900원
# 37 [숲속바람][] 자연을 담은 숲속바람 스탠드 선풍기 14형 가정용 43,000원
# 38 [신일전자]블랙  에어서큘레이터(SIF-FA400A) 93,840원
# 39 ALLDOCUBE iplay50 mini 태블릿 pc 안드로이드 4+64G 글로벌롬버전 103,900원
# 40 [르젠]르젠 무선 BLDC 선풍기(LZDF-CZ740) 99,000원
# 41 [넥스코]넥스코 32단 스텐딩 10인치 써큘레이터 BLDC 리모컨 NKF-3230G 69,000원
# 42 [LG전자]혜택가 50만원대 LG전자 휘센 제습기 20L 블루 DQ202PBBC 빠른배송 558,000원
# 43 [쿠쿠](혜택가 6.1만원) 쿠쿠 본사직영 CR-0675FW 에그 밥솥 6인용 밥솥 69,310원
# 44 [로보락]로보락 S8 Plus 로봇청소기 먼지통 자동비움 장애물 회피 듀얼브러시 물걸레오토리프팅 996,840원
# 45 [아이닉]아이닉 차이슨 무선청소기 i20 엘리트 159,000원
# 46 닌텐도 스위치 젤다의 전설 티어스 오브 더 킹덤 81,000원
# 47 [위닉스]공식인증점)위닉스 17L제습기 {DN3E170-LWK} 1등급 제습기 (롯데카드 35.5만) 381,720원
# 48 [헬로우]공식판매점 헬로 HAYLOU T19 블루투스이어폰 6개월 AS 9,900원
# 49 [신일전자]신일 BLDC 리모컨 써큘레이터 SIF-TW80T 베이지 119,200원
# 50 [필립스]PHILIPS 필립스 코털제거기 NT1620/15 콧털 정리 트리머 15,880원
# 51 내일도착유파 선풍기리모컨초미풍발터치 TSK-3528CR 29,620원
# 52 [레드울프]갤럭시 S23 S22 울트라 노트20/노트10/S21/S20/S10/A53/A32/A23/A33/A71/A82 플러스 가죽 지갑형 폰케이스 19,900원
# 53 [리큐엠]고속충전 잔량표시 20000mAh 보조배터리 QP2000A 20W 36,900원
# 54 [보만]최종 3.5만) 32만개 판매 국민 스팀다리미 보만 핸디형 가정용 휴대용 여행용 의류스팀기 DB8231 37,790원
# 55 [네고]2매+1 (이벤트참여) 강화유리 지문방지 갤럭시S23 S22 울트라 플러스 노트 플립 폴드 아이폰14 13 프로맥스 14,900원
# 56 [마이크로소프트]XBOX Live Gold 12개월 이용권 Xbox Digital Code 라이브골드 12개월 46,800원
# 57 [유파]방송유파 선풍기리모컨초미풍발터치 TSK-3528CR 28,750원
# 58 [윈드피아]가정용 업소용 사무실 스탠드 키높이 선풍기 WA-170 28,600원
# 59 [신일전자]신일 LED 리모컨 스탠드 선풍기 SIF-R14PM 95,900원
# 60 [필립스]PHILIPS 샤티넬 어드밴스 모근제거기 BRE710/10 108,100원
# 61 [로지텍]로지텍 코리아 MK295 SILENT 무소음 무선콤보 39,900원
# 62 [프리플로우]라이젠5 5600G_16GB_500GB 컴퓨터본체 (홈오피스 PRO 5) AMD세잔 사무용/가정용컴퓨터 조립PC 389,000원
# 63 [오닉스북스](빠른직구) 오닉스 북스 포크5 6인치 이북리더기 2+32GB 블랙 2023 최신상 182,500원
# 64 [위닉스]공식인증점) 위닉스 제습기 12L {DXTE120-MPK} 2023년 신상품 (롯데카드 21.9만) 235,480원
# 65 [쿠쿠](혜택가 12.0만원) 쿠쿠 본사직영 35인용 대용량 업소용 전기보온 밥솥 CR-3555B 135,010원
# 66 [Lenovo]PAD 2022 P12 태블릿 샤오신 패드 6+128g 10.6인치 WIFI 글로벌롬 172,800원
# 67 [대우]대우 써큘레이터형 발터치 리모콘 선풍기 48,240원
# 68 [에코백스]에코백스 T10옴니(2년무상AS) 올인원 로봇청소기(물걸레세척.열풍건조.먼지비움) 999,000원
# 69 [Lenovo]레노버 XIAOXINPad 태블릿 4+64G p12 내수용  그레이 149,870원
# 70 [오아]오아 클린이워터B 휴대용 무선 구강세정기 1+1 69,900원
# 71 모닝컴 리모컨 초미세풍 발터치스탠드선풍기 23년도 신상품 37,800원
# 72 ARCTIC P12 PWM PST VALUE PACK 아틱 케이스 시스템 34,900원
# 73 [쿠쿠](혜택가 20.9만원) 쿠쿠 본사직영 CRP-DHP0610FD 6인용 IH전기압력 밥솥 238,510원
# 74 [쿠쿠](혜택가 8.0만원) 쿠쿠 본사직영 5.5L 에어프라이어 CAF-G0610TB 90,550원
# 75 [삼성전자]버티컬 무선마우스 SM-M1300QB 블루투스 멀티페어링 저소음 39,900원
# 76 [젠하이저]젠하이저 최신상 모멘텀4 화이트 /블랙+거치대증정 블루투스 무선헤드폰 M4AEBT M4 389,000원
# 77 [솔러스에어]솔러스에어 탁상용 선풍기 타이머 좌우회전 수면풍 자연풍 무선 무소음 미니 탁상형 소형 충전식 AIR604TF 34,800원
# 78 [아이닉]차이슨 무선청소기 New i20 UV브러시탑재 199,000원
# 79 [위즈웰]WB800 설레임 눈꽃 빙수기 제빙기 빙삭기 눈꽃 빙수기계 팥빙수기계 핑크 화이트 민트 3color 66,900원
# 80 [신일전자]화이트  에어서큘레이터(SIF-FA800B) 93,840원
# 81 [삼성전자]삼성 KU75UA8070FXKR 189cm UHD 스마트 TV 스탠드형 1,524,000원
# 82 [신일전자]2023년 최신상 베이지 1대  BLDC 서큘레이터 air S9(SIF-CS30BG 142,800원
# 83 [아이닉]아이닉 23년형 무선청소기 i30 아이타워 i-Tower 299,000원
# 84 [쿠쿠](혜택가 5.9만원) 쿠쿠 본사직영 20L 전자레인지 CMW-A201DB 67,510원
# 85 [블레스]스마트 터치 핸드블랜더 기본형 SH601 26,900원
# 86 [윈드피아]가정용선풍기 업소용선풍기 스탠드 선풍기 WA-370 26,900원
# 87 [대우]대우 두유제조기 두유메이커 (믹서기능) 콩 두유만들기 이유식 죽 45,900원
# 88 [삼성전자]갤럭시북2 NT550XEZ-A58A 최종56만 가성비노트북 인텔i5탑재 대학생추천 인강용 735,000원
# 89 [풀무원](15%중복할인) 풀무원 스팀쿡 에어프라이어 올스텐 10.5L PSA-W1000 (롯데카드7%할인) 179,000원
# 90 [신일전자]신일 기본형 스탠드 선풍기 SIF-P128 스탠드형 58,900원
# 91 [유파]가성비 발터치 리모컨 선풍기 AKF-FT14R 리모콘 450분 타이머 5엽 날개 서큘레이터 초미풍 사무실 매장 29,800원
# 92 [삼성전자]공식인증 SSD 970 EVO Plus M.2 2TB  MZ-V7S2T0BW (정품) 혜택가134500원 169,860원
# 93 [샤오미]샤오미 보조배터리 7세대 10000mah 국내정발 정품 17,900원
# 94 [ASUS]ASUS ROG ALLY RC71L-NH001W 6차 예약판매 휴대용 게임기 Z1 Extreme/16GB/512GB/UMPC 7.18까지 발송 999,000원
# 95 [솔러스에어](1+1) 솔러스에어 탁상용 선풍기 타이머 좌우회전 수면풍 무선 무소음 미니 탁상형 소형 AIR604TF 65,600원
# 96 [엔보우]모노 탁상용 무선 휴대용 선풍기 3세대 1+1(할인 행사) 29,900원
# 97 [LG전자]LG 27GN650 144Hz 게이밍모니터 1ms 울트라기어 339,000원
# 98 [유닉스]유닉스 전문가용 매직기 미용실 고데기 볼륨 스트레이트너 세라믹 앞머리 고대기 판고데기 추천 31,370원
# 99 [로지텍]로지텍코리아 정품 무선마우스 MX MASTER3 /유니파잉/윈+맥호환/멀티페어링 129,010원
# 100 맥심 모카골드 마일드 170티x6개입 총1020티 136,800원

# %%
import requests
from bs4 import BeautifulSoup

# gmarket best - 컴퓨터/전자 카테고리
# https://www.gmarket.co.kr/n/best?viewType=G&groupCode=G06

# 상품명, 가격
url = "https://www.gmarket.co.kr/n/best?viewType=G&groupCode=G06"

wb = Workbook()
ws = wb.active
ws.title = "20230710컴퓨터전자베스트"

ws.append(["순위","회사명","상품명","가격","상세정보url"])

ws.column_dimensions["B"].width = 30 # 회사명
ws.column_dimensions["C"].width = 30 # 상품명
ws.column_dimensions["D"].width = 30 # 가격
ws.column_dimensions["E"].width = 70 # 상세정보url

res = requests.get(url)

soup = BeautifulSoup(res.text,"html.parser")

best_list = soup.select("div.best-list li")

# enumerate(리스트)

for idx,item in enumerate(best_list,start=1):
    product_info = item.select_one("a.itemname")
    # 상품명
    product_name = product_info.string
    # 링크 추출
    href = product_info["href"]
    # 가격
    product_price = item.select_one("div.s-price > strong span").get_text()
    # 회사명 추출
    product_detail = requests.get(href)
    soup2 = BeautifulSoup(product_detail.text, "html.parser")
    brand = soup2.select_one("span.text__brand > .text")
    if not brand:
        # 셀러 추출
        brand = soup2.select_one("span.text__seller")
    brand_name = brand.get_text().strip()

    # print(idx,brand_name,product_name,product_price,href)
    ws.append([idx,brand_name,product_name,product_price,href])

    ws.cell(row=idx+1,column=5).hyperlink = href

wb.save("gmarket100.xlsx")
wb.close()
